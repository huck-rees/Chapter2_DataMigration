# %%
import os

def create_river_folders(base_directory):
    """
    Create folders for river monitoring stations in the specified directory.
    
    Parameters:
    base_directory (str): The path where folders should be created
    """

    # Create the base directory if it doesn't exist
    if not os.path.exists(base_directory):
        os.makedirs(base_directory)
        print(f"Created base directory: {base_directory}")
    
    # Create each folder
    created_count = 0
    skipped_count = 0
    
    for folder_name in folder_names:
        folder_path = os.path.join(base_directory, folder_name)
        
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
            created_count += 1
            print(f"Created: {folder_name}")
        else:
            skipped_count += 1
            print(f"Already exists: {folder_name}")
    
    print(f"\n✓ Summary: {created_count} folders created, {skipped_count} already existed")
    print(f"Total folders: {len(folder_names)}")

# Run it
target_directory = r"E:\Dissertation\Data\RiverMapping\Reaches"
create_river_folders(target_directory)

# %%
import os
import geopandas as gpd
from pathlib import Path

def convert_gpkg_to_shapefile():
    """
    Convert .gpkg files to shapefiles with specific attributes and reprojection.
    Searches through all planform types and river names, converts each .gpkg to a shapefile
    with a single 'ds_order' attribute set to 1, reprojects to EPSG:3395, and saves to
    the corresponding reach folder.
    """
    
    # Define paths
    source_base = r"E:\Dissertation\Data\Zhao_etal_2025"
    target_base = r"E:\Dissertation\Data\RiverMapping\Reaches"
    
    # Define planform types
    planform_types = ["B", "HSW", "LSW", "Me"]
    
    # Counters for summary
    success_count = 0
    error_count = 0
    not_found_count = 0
    errors = []
    
    # Get list of all river folders from the target directory
    river_folders = [f for f in os.listdir(target_base) 
                    if os.path.isdir(os.path.join(target_base, f))]
    
    print(f"Found {len(river_folders)} river reach folders")
    print(f"Searching through {len(planform_types)} planform types\n")
    
    # Process each river and planform combination
    for river_name in river_folders:
        found_gpkg = False
        
        for planform in planform_types:
            # Construct source path
            source_dir = os.path.join(source_base, planform, river_name)
            source_file = os.path.join(source_dir, f"{river_name}.gpkg")
            
            # Check if the .gpkg file exists
            if os.path.exists(source_file):
                found_gpkg = True
                
                try:
                    # Read the geopackage
                    gdf = gpd.read_file(source_file)
                    
                    # Verify it has exactly one feature
                    if len(gdf) != 1:
                        print(f"⚠ Warning: {river_name} ({planform}) has {len(gdf)} features, expected 1")
                    
                    # Create new GeoDataFrame with only ds_order attribute
                    gdf_new = gpd.GeoDataFrame(
                        {'ds_order': [1]},
                        geometry=gdf.geometry,
                        crs=gdf.crs
                    )
                    
                    # Reproject to EPSG:3395 (WGS 84 / World Mercator)
                    gdf_reprojected = gdf_new.to_crs('EPSG:3395')
                    
                    # Construct output path
                    output_dir = os.path.join(target_base, river_name)
                    output_file = os.path.join(output_dir, f"{river_name}.shp")
                    
                    # Save as shapefile
                    gdf_reprojected.to_file(output_file)
                    
                    success_count += 1
                    print(f"✓ Converted: {river_name} (from {planform})")
                    
                except Exception as e:
                    error_count += 1
                    error_msg = f"{river_name} ({planform})"
                    errors.append(error_msg)
                    print(f"✗ Error: {river_name} ({planform}) - {str(e)}")
                    print(f"   Skipping and continuing with remaining rivers...")
                
                # Break after finding first matching planform (whether success or error)
                break
        
        if not found_gpkg:
            not_found_count += 1
            print(f"○ Not found: {river_name} (checked all planform types)")
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"✓ Successfully converted: {success_count}")
    print(f"○ GPKG files not found: {not_found_count}")
    print(f"✗ Errors encountered: {error_count}")
    print(f"Total river folders processed: {len(river_folders)}")
    
    if errors:
        print(f"\n{'='*60}")
        print(f"FAILED RIVERS")
        print(f"{'='*60}")
        for error in errors:
            print(f"  - {error}")

if __name__ == "__main__":
    print("Starting GPKG to Shapefile conversion...\n")
    convert_gpkg_to_shapefile()
    print("\nConversion process complete!")

# %%
import os

target_base = r"E:\Dissertation\Data\RiverMapping\Reaches"

print(f"Does directory exist? {os.path.exists(target_base)}")
if os.path.exists(target_base):
    folders = [f for f in os.listdir(target_base) if os.path.isdir(os.path.join(target_base, f))]
    print(f"Number of folders found: {len(folders)}")
    if folders:
        print(f"First few folders: {folders[:5]}")

# %%
import os

def get_folder_names_from_directory(directory_path):
    """
    Generate a list of folder names from a given directory.
    
    Parameters:
    directory_path (str): Path to the directory containing folders
    
    Returns:
    list: Sorted list of folder names
    """
    # Get all items in the directory
    all_items = os.listdir(directory_path)
    
    # Filter to only keep directories (not files)
    folder_names = [item for item in all_items 
                   if os.path.isdir(os.path.join(directory_path, item))]
    
    # Sort alphabetically for consistency
    folder_names.sort()
    
    return folder_names

# Use it
directory = r"E:\Dissertation\Data\Zhao_etal_2025\B"
folder_names = get_folder_names_from_directory(directory)

# Print as a Python list that you can copy-paste
print(f"Found {len(folder_names)} folders:\n")
print("folder_names = [")
for i, name in enumerate(folder_names):
    if i < len(folder_names) - 1:
        print(f"    '{name}',")
    else:
        print(f"    '{name}'")
print("]")

# Also print just the count and first few examples
print(f"\nTotal: {len(folder_names)} folders")
if folder_names:
    print(f"First 5: {folder_names[:5]}")
    print(f"Last 5: {folder_names[-5:]}")

# %% [markdown]
# ## This folder creates folders with river names at the given directory
# It will optionally generate an additional subfolder, such as "cleaned" below the river_name folder

# %%
import os

def create_unique_river_folders(base_directory, subfolder_name=None):
    """
    Create folders for river monitoring stations, avoiding duplicates.
    
    Parameters:
    base_directory (str): The path where folders should be created
    subfolder_name (str, optional): If provided, creates a subfolder with this name
                                    inside each river folder
    """
    
    # Raw list of folder names with duplicates
    raw_folder_names = [
        'Amazonas_Tamshiyacu', 'AmuDarya_Kerki', 'Amur_Khabarovsk',
        'Amyl_Kachulka', 'Apalachicola_NearBlountstown', 'Araguaia_Aruana',
        'Araguaia_LuizAlves', 'Araguaia_SaoFelixDoAraguaia', 'Beas_MandiPlain',
        'Beni_Rurrenabaque', 'Benue_Ibi', 'Bhareli_NTRoadCrossing',
        'Brahmaputra_Bahadurabad', 'Brahmaputra_Pandu', 'Brahmaputra_Yangcun',
        'Chenab_Akhnoor', 'Cuiaba_PortoDoAlegre', 'Demini_PostoAjuricaba',
        'Gandak_Dumariaghat', 'Gandak_Triveni', 'Ganges_Paksey',
        'Guapore_Pimenteiras', 'HuangHe_Huayuankou', 'HuangHe_TanglaiQu',
        'Ica_IpirangaVelho', 'Indus_Kotri', 'Irrawaddy_Katha',
        'Irrawaddy_Sagaing', 'Itacuai_LadarioJusante', 'Jurua_EirunepeMontante',
        'Jurua_SantosDumont', 'Katun_Srostki', 'Kokcha_Khojaghar',
        'Krishna_Vijayawada', 'Lena_Tabaga', 'Liard_UpperCrossing',
        'Logone_Bongor', 'Logone_Lai', 'Madeira_Humaita',
        'Mamore_Guajara-Mirim', 'Mamore_PuertoSiles', 'Maranon_Borja',
        'Maranon_SanRegis', 'Mortes_SantoAntonioDoLeverger', 'Napo_Bellavista',
        'Napo_NvoRocafuerte', 'Naryn_UstKekirim', 'Ob_Prokhorkino',
        'Panj_NizPyandzh', 'Parana_Corrientes', 'Peace_FifthMeridian',
        'Pilcomayo_VillaMontes', 'Purus_Canutama', 'Purus_Labrea',
        'Purus_SeringalDaCaridade', 'Purus_ValparaisoMontante', 'Red_Index',
        'Rufiji_Stigler', 'Salinas_SanAugustin', 'SaoFrancisco_BomJesusDaLapa',
        'SaoFrancisco_Morpara', 'SaptKosi_Baltara', 'SaptKosi_Chatara-Kothu',
        'Selenga_Naushki', 'Solimoes_SantoAntonioDoIca', 'Solimoes_SaoPauloDeOlivenca',
        'Solimoes_Tabatinga', 'Taku_NearTulsequa', 'Tanana_NearHardingLake',
        'Tarauaca_Envira', 'Tista_AndersonBr', 'Tista_Kaunia',
        'Tisza_Vylok', 'Trinity_Romayor', 'Ucayali_Atalaya',
        'Ucayali_Pucallpa', 'Ucayali_Requena', 'Ural_Kushum',
        'White_DevallsBluff', 'White_Petersburg', 'Yukon_NearStevensVillage',
        'Zambezi_Sesheke', 'Beni', 'Beni', 'Beni', 'Beni', 'Beni',
        'Beni', 'Beni', 'Beni', 'Beni', 'Beni', 'Bermejo', 'Bermejo',
        'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo',
        'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo',
        'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo', 'Bermejo',
        'Koyukuk_Huslia', 'Yukon_Beaver', 'Aladan_VerkhoyanskiyPerevoz',
        'Amazonas_Jatuarana', 'Amur_Komsomolsk', 'Benue_Umaisha',
        'BolshayaKet_Rodyonovka', 'Brahmaputra_Pasighat', 'Chari_Bousso',
        'Chari_Guelengdeng', 'Chari_Ndjamena', 'Chari_Sahr', 'Fraser_Hope',
        'Gandak_Devghat', 'Helmand_Kajaki', 'Helmand_Malakhan', 'Indus_Attock',
        'Irtysh_Bobrovsky', 'Irtysh_Hanti-Mansisk', 'Irtysh_Pavlodar',
        'Irtysh_Semiyarskoje', 'Jutai_PortoSeguro', 'Kamchatka_Kozyrevsk',
        'Kan_Kansk', 'MadreDeDios_CachuelaEsperanza', 'Magdalena_Calamar',
        'Magdalena_PuertoBerrio', 'Manas_Mathanguri', 'Mbam_Goura',
        'Mekong_Kratie', 'Niger_Tossaye', 'Ob_Barnaul', 'Ob_Kolpashevo',
        'Ob_Mogochin', 'Ob_Phominskoje', 'Orinoco_CiudadBolivar',
        'Orinoco_Musinacio', 'Paraguay_Asuncion', 'Paraguay_PortoMurtinho',
        'Parana_Chapeton', 'Porcupine_NearFortYukon', 'Sangha_Ouesso',
        'Solimoes_Itapeua', 'Solimoes_Manacapuru', 'SonghuaJiang_Haerbin',
        'Vilyuy_KhatyrykKhoma', 'Yangtze_Datong', 'Yellowstone_NearSidney',
        'Yukon_Eagle', 'Zambezi_LukuluMission', 'Zambezi_Matundo-Cais'
    ]
    
    # Remove duplicates while preserving order
    seen = set()
    folder_names = []
    duplicates_removed = []
    
    for name in raw_folder_names:
        if name not in seen:
            seen.add(name)
            folder_names.append(name)
        else:
            duplicates_removed.append(name)
    
    # Report on duplicates
    if duplicates_removed:
        from collections import Counter
        duplicate_counts = Counter(raw_folder_names)
        print("Duplicate rivers found and removed:")
        for name, count in duplicate_counts.items():
            if count > 1:
                print(f"  - {name}: appeared {count} times, keeping 1")
        print()
    
    # Create the base directory if it doesn't exist
    if not os.path.exists(base_directory):
        os.makedirs(base_directory)
        print(f"Created base directory: {base_directory}\n")
    
    # Create each folder
    created_count = 0
    skipped_count = 0
    subfolders_created = 0
    subfolders_skipped = 0
    
    for folder_name in folder_names:
        folder_path = os.path.join(base_directory, folder_name)
        
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
            created_count += 1
            print(f"Created: {folder_name}")
        else:
            skipped_count += 1
            print(f"Already exists: {folder_name}")
        
        # Create subfolder if specified
        if subfolder_name:
            subfolder_path = os.path.join(folder_path, subfolder_name)
            if not os.path.exists(subfolder_path):
                os.makedirs(subfolder_path)
                subfolders_created += 1
            else:
                subfolders_skipped += 1
    
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"Original list: {len(raw_folder_names)} entries")
    print(f"Duplicates removed: {len(duplicates_removed)}")
    print(f"Unique folders: {len(folder_names)}")
    print(f"✓ Folders created: {created_count}")
    print(f"○ Already existed: {skipped_count}")
    
    if subfolder_name:
        print(f"\nSubfolder '{subfolder_name}':")
        print(f"✓ Created: {subfolders_created}")
        print(f"○ Already existed: {subfolders_skipped}")

if __name__ == "__main__":
    # Specify your target directory here
    target_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"  # Change this to your desired path
    
    # Optional: specify a subfolder name to create inside each river folder
    # Set to None if you don't want subfolders
    subfolder = "Cleaned"  # Example: "masks" or "data" or None
    
    create_unique_river_folders(target_directory, subfolder_name=subfolder)

# %% [markdown]
# This moves the Greenberg et al 2024 masks from his folder structure to the new folder structure

# %%
import os
import shutil

def move_greenberg_masks():
    """
    Move .tif mask files from Greenberg et al. directory structure to RiverMapping directory.
    Searches through all planform types and river names, finds mask folders, and moves
    all .tif files to the new directory structure.
    """
    
    # Define paths
    source_base = r"E:\Dissertation\Data\Greenberg_etal_2024\RiverData"
    target_base = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    
    # Define planform types
    planform_types = ["B", "HSW", "LSW", "Me"]
    
    # Counters for summary
    rivers_processed = 0
    files_moved = 0
    rivers_not_found = 0
    rivers_with_multiple_folders = 0
    errors = []
    rivers_with_masks = []
    rivers_without_masks = []
    rivers_with_ambiguous_structure = []
    
    # Get list of all potential river names by scanning all planform directories
    all_river_names = set()
    for planform in planform_types:
        planform_dir = os.path.join(source_base, planform)
        if os.path.exists(planform_dir):
            river_dirs = [d for d in os.listdir(planform_dir) 
                         if os.path.isdir(os.path.join(planform_dir, d))]
            all_river_names.update(river_dirs)
    
    all_river_names = sorted(all_river_names)
    print(f"Found {len(all_river_names)} unique river names across all planform types")
    print(f"Searching through {len(planform_types)} planform types\n")
    
    # Process each river
    for river_name in all_river_names:
        found_masks = False
        
        # Search through planform types for this river
        for planform in planform_types:
            # Construct source path to river directory
            river_dir = os.path.join(source_base, planform, river_name)
            
            if not os.path.exists(river_dir):
                continue
            
            # Check what's inside the river directory
            items_in_river_dir = [d for d in os.listdir(river_dir) 
                                 if os.path.isdir(os.path.join(river_dir, d))]
            
            # Look for potential search locations
            waterlevel_folders = [f for f in items_in_river_dir if f.startswith('WaterLevel')]
            has_mask_direct = 'mask' in items_in_river_dir
            has_river_subfolder = river_name in items_in_river_dir
            
            # Determine the correct path to mask folder
            mask_dir = None
            all_waterlevel_folders = []
            
            # Collect all WaterLevel folders from both levels
            if waterlevel_folders:
                all_waterlevel_folders.extend(waterlevel_folders)
            
            # Also check inside river_name subfolder if it exists
            if has_river_subfolder:
                river_subfolder = os.path.join(river_dir, river_name)
                subfolders = [d for d in os.listdir(river_subfolder) 
                             if os.path.isdir(os.path.join(river_subfolder, d))]
                subfolder_waterlevels = [f for f in subfolders if f.startswith('WaterLevel')]
                all_waterlevel_folders.extend(subfolder_waterlevels)
            
            # Case 1: Multiple WaterLevel folders across both levels - ambiguous
            if len(all_waterlevel_folders) > 1:
                found_masks = True  # Mark as found to avoid "not found" message
                rivers_with_ambiguous_structure.append(river_name)
                rivers_with_multiple_folders += 1
                print(f"⚠ Warning: {river_name} ({planform}) has multiple WaterLevel folders: {all_waterlevel_folders}")
                print(f"   Skipping due to ambiguous structure...")
                break
            
            # Case 2: WaterLevel folder directly in river_dir
            elif len(waterlevel_folders) == 1:
                potential_mask_dir = os.path.join(river_dir, waterlevel_folders[0], "mask")
                if os.path.exists(potential_mask_dir) and os.path.isdir(potential_mask_dir):
                    mask_dir = potential_mask_dir
            
            # Case 3: WaterLevel folder inside river_name subfolder
            elif has_river_subfolder:
                river_subfolder = os.path.join(river_dir, river_name)
                subfolders = [d for d in os.listdir(river_subfolder) 
                             if os.path.isdir(os.path.join(river_subfolder, d))]
                subfolder_waterlevels = [f for f in subfolders if f.startswith('WaterLevel')]
                
                if len(subfolder_waterlevels) == 1:
                    potential_mask_dir = os.path.join(river_subfolder, subfolder_waterlevels[0], "mask")
                    if os.path.exists(potential_mask_dir) and os.path.isdir(potential_mask_dir):
                        mask_dir = potential_mask_dir
                elif 'mask' in subfolders:
                    # No WaterLevel, but mask exists directly in river_name subfolder
                    mask_dir = os.path.join(river_subfolder, "mask")
            
            # Case 4: mask folder directly in river_dir (no river_name subfolder, no WaterLevel)
            elif has_mask_direct:
                mask_dir = os.path.join(river_dir, "mask")
            
            # If we found a mask directory, process it
            if mask_dir:
                # Get all .tif files in the mask directory
                tif_files = [f for f in os.listdir(mask_dir) if f.lower().endswith('.tif')]
                
                if tif_files:
                    found_masks = True
                    
                    try:
                        # Create target directory
                        target_dir = os.path.join(target_base, river_name, "Cleaned")
                        os.makedirs(target_dir, exist_ok=True)
                        
                        # Move each .tif file
                        files_moved_for_river = 0
                        for tif_file in tif_files:
                            source_file = os.path.join(mask_dir, tif_file)
                            target_file = os.path.join(target_dir, tif_file)
                            
                            shutil.move(source_file, target_file)
                            files_moved_for_river += 1
                        
                        files_moved += files_moved_for_river
                        rivers_processed += 1
                        rivers_with_masks.append(river_name)
                        print(f"✓ Moved {files_moved_for_river} file(s): {river_name} (from {planform})")
                        
                    except Exception as e:
                        error_msg = f"{river_name} ({planform})"
                        errors.append(error_msg)
                        print(f"✗ Error: {river_name} ({planform}) - {str(e)}")
                        print(f"   Skipping and continuing with remaining rivers...")
                    
                    # Break after finding first matching planform with masks
                    break
        
        if not found_masks:
            rivers_without_masks.append(river_name)
            rivers_not_found += 1
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"✓ Rivers with masks processed: {rivers_processed}")
    print(f"✓ Total .tif files moved: {files_moved}")
    print(f"○ Rivers without mask folders: {rivers_not_found}")
    print(f"⚠ Rivers with ambiguous structure (skipped): {rivers_with_multiple_folders}")
    print(f"✗ Errors encountered: {len(errors)}")
    print(f"Total unique rivers scanned: {len(all_river_names)}")
    
    if rivers_with_ambiguous_structure:
        print(f"\n{'='*60}")
        print(f"RIVERS WITH AMBIGUOUS STRUCTURE (Multiple WaterLevel Folders)")
        print(f"{'='*60}")
        for river in rivers_with_ambiguous_structure:
            print(f"  - {river}")
    
    if errors:
        print(f"\n{'='*60}")
        print(f"FAILED RIVERS")
        print(f"{'='*60}")
        for error in errors:
            print(f"  - {error}")
    
    # Optional: Print rivers without masks (useful for debugging)
    if rivers_without_masks and len(rivers_without_masks) <= 20:
        print(f"\n{'='*60}")
        print(f"RIVERS WITHOUT MASK FOLDERS (showing up to 20)")
        print(f"{'='*60}")
        for river in rivers_without_masks[:20]:
            print(f"  - {river}")
        if len(rivers_without_masks) > 20:
            print(f"  ... and {len(rivers_without_masks) - 20} more")

if __name__ == "__main__":
    print("Starting mask file migration...\n")
    move_greenberg_masks()
    print("\nMask migration complete!")

# %% [markdown]
# This moves the Zhao et al 2025 masks from his folder structure to the new folder structure

# %%
def move_zhao_masks():
    """
    Move .tif mask files from Zhao et al. directory structure to RiverMapping directory.
    Searches through all planform types and river names, finds PreparedImagery_annual folders,
    and moves all .tif files to the new directory structure.
    """
    
    # Define paths
    source_base = r"E:\Dissertation\Data\Zhao_etal_2025"
    target_base = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    
    # Define planform types
    planform_types = ["B", "HSW", "LSW", "Me"]
    
    # Counters for summary
    rivers_processed = 0
    files_moved = 0
    rivers_not_found = 0
    errors = []
    rivers_with_masks = []
    rivers_without_masks = []
    
    # Get list of all potential river names by scanning all planform directories
    all_river_names = set()
    for planform in planform_types:
        planform_dir = os.path.join(source_base, planform)
        if os.path.exists(planform_dir):
            river_dirs = [d for d in os.listdir(planform_dir) 
                         if os.path.isdir(os.path.join(planform_dir, d))]
            all_river_names.update(river_dirs)
    
    all_river_names = sorted(all_river_names)
    print(f"Found {len(all_river_names)} unique river names across all planform types")
    print(f"Searching through {len(planform_types)} planform types\n")
    
    # Process each river
    for river_name in all_river_names:
        found_masks = False
        
        # Search through planform types for this river
        for planform in planform_types:
            # Construct source path: planform/river_name/PreparedImagery_annual/river_name
            river_dir = os.path.join(source_base, planform, river_name)
            imagery_dir = os.path.join(river_dir, "PreparedImagery_annual")
            mask_dir = os.path.join(imagery_dir, river_name)
            
            # Check if mask directory exists
            if os.path.exists(mask_dir) and os.path.isdir(mask_dir):
                # Get all .tif files in the directory
                tif_files = [f for f in os.listdir(mask_dir) if f.lower().endswith('.tif')]
                
                if tif_files:
                    found_masks = True
                    
                    try:
                        # Create target directory
                        target_dir = os.path.join(target_base, river_name, "Cleaned")
                        os.makedirs(target_dir, exist_ok=True)
                        
                        # Move each .tif file
                        files_moved_for_river = 0
                        for tif_file in tif_files:
                            source_file = os.path.join(mask_dir, tif_file)
                            target_file = os.path.join(target_dir, tif_file)
                            
                            shutil.move(source_file, target_file)
                            files_moved_for_river += 1
                        
                        files_moved += files_moved_for_river
                        rivers_processed += 1
                        rivers_with_masks.append(river_name)
                        print(f"✓ Moved {files_moved_for_river} file(s): {river_name} (from {planform})")
                        
                    except Exception as e:
                        error_msg = f"{river_name} ({planform})"
                        errors.append(error_msg)
                        print(f"✗ Error: {river_name} ({planform}) - {str(e)}")
                        print(f"   Skipping and continuing with remaining rivers...")
                    
                    # Break after finding first matching planform with masks
                    break
        
        if not found_masks:
            rivers_without_masks.append(river_name)
            rivers_not_found += 1
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"✓ Rivers with masks processed: {rivers_processed}")
    print(f"✓ Total .tif files moved: {files_moved}")
    print(f"○ Rivers without mask folders: {rivers_not_found}")
    print(f"✗ Errors encountered: {len(errors)}")
    print(f"Total unique rivers scanned: {len(all_river_names)}")
    
    if errors:
        print(f"\n{'='*60}")
        print(f"FAILED RIVERS")
        print(f"{'='*60}")
        for error in errors:
            print(f"  - {error}")
    
    # Optional: Print rivers without masks (useful for debugging)
    if rivers_without_masks and len(rivers_without_masks) <= 20:
        print(f"\n{'='*60}")
        print(f"RIVERS WITHOUT MASK FOLDERS (showing up to 20)")
        print(f"{'='*60}")
        for river in rivers_without_masks[:20]:
            print(f"  - {river}")
        if len(rivers_without_masks) > 20:
            print(f"  ... and {len(rivers_without_masks) - 20} more")


if __name__ == "__main__":
    print("Starting Greenberg mask file migration...\n")
    move_greenberg_masks()
    print("\nGreenberg mask migration complete!")
    
    print("\n" + "="*60)
    print("\nStarting Zhao mask file migration...\n")
    move_zhao_masks()
    print("\nZhao mask migration complete!")

# %% [markdown]
# Preliminary QC of river masks

# %%
import os
import numpy as np
import pandas as pd
import rasterio
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from datetime import datetime

def analyze_mask_statistics(mask_dir):
    """
    Analyze all .tif masks in a directory and compute statistics.
    
    Parameters:
    -----------
    mask_dir : str
        Path to directory containing .tif mask files
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with statistics for each mask
    """
    tif_files = sorted([f for f in os.listdir(mask_dir) if f.lower().endswith('.tif')])
    
    if not tif_files:
        return None
    
    stats_list = []
    
    for tif_file in tif_files:
        file_path = os.path.join(mask_dir, tif_file)
        
        try:
            # Suppress the NotGeoreferencedWarning
            import warnings
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
                with rasterio.open(file_path) as src:
                    data = src.read(1)  # Read first band
            
            # Get unique values to check what's actually in the data
            unique_vals = np.unique(data)
            
            # Convert data to float for consistent handling
            data = data.astype(np.float64)
            
            # Count pixels
            total_pixels = data.size
            
            # Detect if this is a 0/1 mask or 0/255 mask
            # Check if any values are close to 255
            has_255 = np.any(np.abs(data - 255) < 0.01)
            
            if has_255:
                # This is a 0/255 mask (Zhao study)
                is_zero = np.abs(data - 0) < 0.01
                is_wet = np.abs(data - 255) < 0.01
                wet_pixels = np.sum(is_wet)
                dry_pixels = np.sum(is_zero)
                other_pixels = total_pixels - wet_pixels - dry_pixels
            else:
                # This is a 0/1 mask (Greenberg study)
                is_zero = np.abs(data - 0) < 0.01
                is_one = np.abs(data - 1) < 0.01
                wet_pixels = np.sum(is_one)
                dry_pixels = np.sum(is_zero)
                other_pixels = total_pixels - wet_pixels - dry_pixels
            
            # Calculate percentages
            pct_wet = (wet_pixels / total_pixels) * 100 if total_pixels > 0 else 0
            pct_dry = (dry_pixels / total_pixels) * 100 if total_pixels > 0 else 0
            
            stats_list.append({
                'filename': tif_file,
                'total_pixels': total_pixels,
                'wet_pixels': wet_pixels,
                'dry_pixels': dry_pixels,
                'other_pixels': other_pixels,
                'pct_wet': pct_wet,
                'pct_dry': pct_dry,
                'unique_values': str(unique_vals.tolist())
            })
            
        except Exception as e:
            print(f"  Error reading {tif_file}: {e}")
            stats_list.append({
                'filename': tif_file,
                'total_pixels': 0,
                'wet_pixels': 0,
                'dry_pixels': 0,
                'other_pixels': 0,
                'pct_wet': 0,
                'pct_dry': 0,
                'unique_values': '',
                'error': str(e)
            })
    
    return pd.DataFrame(stats_list)

def flag_problematic_masks(df, z_threshold=3):
    """
    Flag masks that deviate significantly from the mean or have other issues.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame with mask statistics
    z_threshold : float
        Z-score threshold for flagging outliers
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with added flag columns
    """
    # Calculate z-scores for wet pixels
    mean_wet = df['wet_pixels'].mean()
    std_wet = df['wet_pixels'].std()
    
    if std_wet > 0:
        df['z_score'] = (df['wet_pixels'] - mean_wet) / std_wet
    else:
        df['z_score'] = 0
    
    # Flag different types of problems
    df['flag_all_dry'] = df['wet_pixels'] == 0
    df['flag_all_wet'] = df['pct_wet'] > 99.9
    df['flag_extreme_outlier'] = np.abs(df['z_score']) > z_threshold
    df['flag_non_binary'] = df['other_pixels'] > 0
    df['flag_tiny_wet'] = (df['pct_wet'] < 0.1) & (df['pct_wet'] > 0)
    
    # Overall flag
    df['flagged'] = (df['flag_all_dry'] | df['flag_all_wet'] | 
                     df['flag_extreme_outlier'] | df['flag_non_binary'] | 
                     df['flag_tiny_wet'])
    
    return df

def create_contact_sheet(mask_dir, df, output_path, max_images=40):
    """
    Create a contact sheet showing all masks with flagged ones highlighted.
    
    Parameters:
    -----------
    mask_dir : str
        Path to directory containing masks
    df : pandas.DataFrame
        DataFrame with mask statistics and flags
    output_path : str
        Path to save the contact sheet image
    max_images : int
        Maximum number of images to show
    """
    tif_files = df['filename'].tolist()[:max_images]
    n_images = len(tif_files)
    
    # Calculate grid dimensions
    n_cols = min(8, n_images)
    n_rows = int(np.ceil(n_images / n_cols))
    
    fig = plt.figure(figsize=(20, n_rows * 2.5))
    
    for idx, tif_file in enumerate(tif_files):
        file_path = os.path.join(mask_dir, tif_file)
        
        try:
            # Suppress the NotGeoreferencedWarning
            import warnings
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
                with rasterio.open(file_path) as src:
                    data = src.read(1)
            
            ax = plt.subplot(n_rows, n_cols, idx + 1)
            ax.imshow(data, cmap='Blues', vmin=0, vmax=1)
            
            # Highlight flagged images with red border
            row = df[df['filename'] == tif_file].iloc[0]
            if row['flagged']:
                for spine in ax.spines.values():
                    spine.set_edgecolor('red')
                    spine.set_linewidth(3)
            
            # Add title with basic info
            title = f"{tif_file[:15]}...\n"
            title += f"Wet: {row['pct_wet']:.1f}%"
            if row['flagged']:
                title += "\n⚠ FLAGGED"
            
            ax.set_title(title, fontsize=8, color='red' if row['flagged'] else 'black')
            ax.axis('off')
            
        except Exception as e:
            print(f"  Error visualizing {tif_file}: {e}")
    
    plt.tight_layout()
    plt.savefig(output_path, dpi=150, bbox_inches='tight')
    plt.close()

def create_time_series_plot(df, output_path, river_name):
    """
    Create a time series plot of wet pixels over time.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame with mask statistics
    output_path : str
        Path to save the plot
    river_name : str
        Name of the river for the title
    """
    fig, ax = plt.subplots(figsize=(14, 6))
    
    x = np.arange(len(df))
    
    # Plot all points
    ax.plot(x, df['wet_pixels'], 'o-', color='steelblue', markersize=4, label='Normal')
    
    # Highlight flagged points
    flagged_df = df[df['flagged']]
    if not flagged_df.empty:
        flagged_indices = flagged_df.index
        ax.plot(flagged_indices, flagged_df['wet_pixels'], 'ro', 
                markersize=8, label='Flagged', zorder=5)
    
    # Add mean line
    mean_wet = df['wet_pixels'].mean()
    ax.axhline(mean_wet, color='green', linestyle='--', alpha=0.7, label=f'Mean: {mean_wet:.0f}')
    
    # Add ±3 std lines
    std_wet = df['wet_pixels'].std()
    ax.axhline(mean_wet + 3*std_wet, color='red', linestyle=':', alpha=0.5, label='±3 σ')
    ax.axhline(mean_wet - 3*std_wet, color='red', linestyle=':', alpha=0.5)
    
    ax.set_xlabel('Mask Index', fontsize=12)
    ax.set_ylabel('Wet Pixels', fontsize=12)
    ax.set_title(f'{river_name} - Wet Pixel Count Over Time', fontsize=14, fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(output_path, dpi=150, bbox_inches='tight')
    plt.close()

def screen_all_rivers(base_dir, output_dir, z_threshold=3, create_visualizations=True):
    """
    Screen all river mask directories and generate reports.
    
    Parameters:
    -----------
    base_dir : str
        Base directory containing river folders
    output_dir : str
        Directory to save QC reports
    z_threshold : float
        Z-score threshold for flagging outliers
    create_visualizations : bool
        Whether to create contact sheets and plots (slower)
    """
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Get all river directories
    river_dirs = [d for d in os.listdir(base_dir) 
                  if os.path.isdir(os.path.join(base_dir, d))]
    river_dirs = sorted(river_dirs)
    
    print(f"Found {len(river_dirs)} river directories\n")
    
    # Track overall QC status
    qc_summary = []
    
    for river_idx, river_name in enumerate(river_dirs, 1):
        print(f"[{river_idx}/{len(river_dirs)}] Processing {river_name}...", end='', flush=True)
        
        # Path to masks
        mask_dir = os.path.join(base_dir, river_name, "reach_1", "Cleaned")
        
        if not os.path.exists(mask_dir):
            print(f" ⚠ No 'Cleaned' folder found, skipping")
            qc_summary.append({
                'river_name': river_name,
                'status': 'No masks found',
                'total_masks': 0,
                'flagged_masks': 0,
                'qc_complete': False
            })
            continue
        
        # Analyze masks
        print(f" Analyzing...", end='', flush=True)
        df = analyze_mask_statistics(mask_dir)
        
        if df is None or len(df) == 0:
            print(f" ⚠ No .tif files found, skipping")
            qc_summary.append({
                'river_name': river_name,
                'status': 'No .tif files',
                'total_masks': 0,
                'flagged_masks': 0,
                'qc_complete': False
            })
            continue
        
        # Flag problematic masks
        print(f" Flagging...", end='', flush=True)
        df = flag_problematic_masks(df, z_threshold)
        
        # Create river-specific output directory
        river_output_dir = os.path.join(output_dir, river_name)
        os.makedirs(river_output_dir, exist_ok=True)
        
        # Save statistics CSV
        print(f" Saving CSV...", end='', flush=True)
        csv_path = os.path.join(river_output_dir, f"{river_name}_statistics.csv")
        df.to_csv(csv_path, index=False)
        
        if create_visualizations:
            # Create contact sheet
            print(f" Contact sheet...", end='', flush=True)
            contact_sheet_path = os.path.join(river_output_dir, f"{river_name}_contact_sheet.png")
            try:
                create_contact_sheet(mask_dir, df, contact_sheet_path)
            except Exception as e:
                print(f" [Contact sheet error: {e}]", end='', flush=True)
            
            # Create time series plot
            print(f" Time series...", end='', flush=True)
            timeseries_path = os.path.join(river_output_dir, f"{river_name}_timeseries.png")
            try:
                create_time_series_plot(df, timeseries_path, river_name)
            except Exception as e:
                print(f" [Time series error: {e}]", end='', flush=True)
        
        # Summary stats
        total_masks = len(df)
        flagged_count = df['flagged'].sum()
        
        print(f" ✓ {total_masks} masks, {flagged_count} flagged")
        
        qc_summary.append({
            'river_name': river_name,
            'status': 'Processed',
            'total_masks': total_masks,
            'flagged_masks': flagged_count,
            'pct_flagged': (flagged_count / total_masks * 100) if total_masks > 0 else 0,
            'qc_complete': False,
            'date_screened': datetime.now().strftime('%Y-%m-%d'),
            'notes': ''
        })
    
    # Save overall QC tracking file
    qc_df = pd.DataFrame(qc_summary)
    qc_tracking_path = os.path.join(output_dir, 'QC_tracking.csv')
    qc_df.to_csv(qc_tracking_path, index=False)
    
    print(f"\n{'='*60}")
    print(f"SCREENING COMPLETE")
    print(f"{'='*60}")
    print(f"Total rivers screened: {len(river_dirs)}")
    print(f"QC tracking file saved to: {qc_tracking_path}")
    print(f"Individual river reports saved to: {output_dir}")
    print(f"\nRivers with flagged masks:")
    for _, row in qc_df[qc_df['flagged_masks'] > 0].iterrows():
        print(f"  - {row['river_name']}: {row['flagged_masks']}/{row['total_masks']} masks flagged")

if __name__ == "__main__":
    # Set your paths here
    base_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    output_directory = r"E:\Dissertation\Data\RiverMapping\MaskQC"
    
    # Run the screening
    # Set create_visualizations=False for faster CSV-only mode
    screen_all_rivers(base_directory, output_directory, z_threshold=3, create_visualizations=False)

# %% [markdown]
# ## Interactive QC viewer

# %%
# %matplotlib qt
# or
# %matplotlib tk

import os
import pandas as pd
import numpy as np
import rasterio
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import ipywidgets as widgets
from datetime import datetime
import warnings

class JupyterMaskQCViewer:
    """
    Jupyter notebook widget-based viewer for QC'ing river masks.
    Similar interface to the GEE validation script.
    """
    
    def __init__(self, qc_dir, base_mask_dir):
        self.qc_dir = qc_dir
        self.base_mask_dir = base_mask_dir
        self.current_river_idx = 0
        self.current_mask_idx = 0
        
        # Load QC tracking
        self.qc_tracking = pd.read_csv(os.path.join(qc_dir, 'QC_tracking.csv'))
        
        # Filter to rivers that need QC (prioritize flagged, then incomplete)
        self.rivers_to_qc = self.qc_tracking[
            (self.qc_tracking['flagged_masks'] > 0) | 
            (self.qc_tracking['qc_complete'] == False)
        ].copy()
        
        self.rivers_to_qc = self.rivers_to_qc.sort_values('pct_flagged', ascending=False)
        
        # Initialize results tracking
        self.qc_results_path = os.path.join(qc_dir, 'mask_qc_results.csv')
        try:
            self.qc_results = pd.read_csv(self.qc_results_path)
            print(f"Loaded existing QC results: {len(self.qc_results)} classifications")
        except FileNotFoundError:
            self.qc_results = pd.DataFrame(columns=[
                'River_Name', 'Filename', 'Classification', 
                'Wet_Pct', 'Z_Score', 'Flagged', 'Timestamp'
            ])
            print("Created new QC results DataFrame")
        
        print(f"Found {len(self.rivers_to_qc)} rivers needing QC")
        print(f"Rivers with flagged masks: {(self.rivers_to_qc['flagged_masks'] > 0).sum()}\n")
        
        self.setup_widgets()
    
    def load_river_data(self, river_name):
        """Load statistics CSV for a river."""
        csv_path = os.path.join(self.qc_dir, river_name, f"{river_name}_statistics.csv")
        if os.path.exists(csv_path):
            df = pd.read_csv(csv_path)
            # Sort by flagged first, then by z_score magnitude
            df['abs_z'] = df['z_score'].abs()
            df = df.sort_values(['flagged', 'abs_z'], ascending=[False, False])
            return df
        return None
    
    def setup_widgets(self):
        """Create all UI widgets."""
        # Info display
        self.info_text = widgets.HTML()
        
        # Mask display output
        self.mask_output = widgets.Output()
        
        # Classification buttons
        self.btn_good = widgets.Button(
            description='✓ Good Mask',
            button_style='success',
            layout=widgets.Layout(width='150px')
        )
        self.btn_delete = widgets.Button(
            description='✗ Delete',
            button_style='danger',
            layout=widgets.Layout(width='150px')
        )
        self.btn_review = widgets.Button(
            description='? Further Review',
            button_style='warning',
            layout=widgets.Layout(width='150px')
        )
        
        # Navigation buttons
        self.btn_prev = widgets.Button(
            description='← Prev Mask',
            layout=widgets.Layout(width='120px')
        )
        self.btn_next = widgets.Button(
            description='Next Mask →',
            layout=widgets.Layout(width='120px')
        )
        self.btn_next_river = widgets.Button(
            description='Next River ⇒',
            button_style='info',
            layout=widgets.Layout(width='120px')
        )
        self.btn_save = widgets.Button(
            description='💾 Save Progress',
            button_style='',
            layout=widgets.Layout(width='120px')
        )
        
        # Connect button callbacks
        self.btn_good.on_click(lambda b: self.classify('Good'))
        self.btn_delete.on_click(lambda b: self.classify('Delete'))
        self.btn_review.on_click(lambda b: self.classify('Review'))
        self.btn_prev.on_click(lambda b: self.navigate(-1))
        self.btn_next.on_click(lambda b: self.navigate(1))
        self.btn_next_river.on_click(lambda b: self.finish_river())
        self.btn_save.on_click(lambda b: self.save_results())
        
        # Layout
        self.ui = widgets.VBox([
            self.info_text,
            widgets.HBox([self.btn_good, self.btn_delete, self.btn_review]),
            widgets.HBox([self.btn_prev, self.btn_next, self.btn_next_river, self.btn_save])
        ])
    
    def show_river(self, river_idx):
        """Load and start showing masks for a specific river."""
        if river_idx >= len(self.rivers_to_qc):
            self.info_text.value = "<h3 style='color: green;'>✓ All rivers QC'd!</h3>"
            self.mask_output.clear_output()
            return
        
        self.current_river_idx = river_idx
        river_row = self.rivers_to_qc.iloc[river_idx]
        self.current_river_name = river_row['river_name']
        
        # Load river data
        self.current_df = self.load_river_data(self.current_river_name)
        if self.current_df is None:
            print(f"No statistics found for {self.current_river_name}, skipping...")
            self.show_river(river_idx + 1)
            return
        
        self.current_mask_idx = 0
        print(f"\n{'='*60}")
        print(f"River {river_idx + 1}/{len(self.rivers_to_qc)}: {self.current_river_name}")
        print(f"Total masks: {river_row['total_masks']}, Flagged: {river_row['flagged_masks']}")
        print(f"{'='*60}\n")
        
        self.show_mask()
    
    def show_mask(self):
        """Display the current mask."""
        if self.current_mask_idx >= len(self.current_df):
            self.finish_river()
            return
        
        row = self.current_df.iloc[self.current_mask_idx]
        mask_path = os.path.join(self.base_mask_dir, self.current_river_name, 
                                 "reach_1", "Cleaned", row['filename'])
        
        # Update info text
        river_row = self.rivers_to_qc.iloc[self.current_river_idx]
        flag_text = ""
        if row['flagged']:
            flags = []
            if row['flag_all_dry']: flags.append("All Dry")
            if row['flag_all_wet']: flags.append("All Wet")
            if row['flag_extreme_outlier']: flags.append("Extreme Outlier")
            if row['flag_non_binary']: flags.append("Non-Binary")
            if row['flag_tiny_wet']: flags.append("Tiny Wet Area")
            flag_text = f"<br><span style='color: red; font-weight: bold;'>⚠ FLAGGED: {', '.join(flags)}</span>"
        
        self.info_text.value = f"""
        <h3>{self.current_river_name} - Mask {self.current_mask_idx + 1}/{len(self.current_df)}</h3>
        <b>River:</b> {self.current_river_idx + 1}/{len(self.rivers_to_qc)} | 
        <b>File:</b> {row['filename']}<br>
        <b>Wet:</b> {row['pct_wet']:.2f}% | <b>Z-score:</b> {row['z_score']:.2f}{flag_text}
        """
        
        # Load and display mask in a new popup figure window
        try:
            # Close any existing figures first
            plt.close('all')
            
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
                with rasterio.open(mask_path) as src:
                    data = src.read(1)
            
            # Normalize for display
            data_normalized = data / data.max() if data.max() > 0 else data
            
            # Create a new figure window (popup)
            plt.figure(figsize=(12, 10))
            ax = plt.gca()
            im = ax.imshow(data_normalized, cmap='Blues', vmin=0, vmax=1)
            
            # Title with all info
            title = f"{self.current_river_name} - Mask {self.current_mask_idx + 1}/{len(self.current_df)}\n"
            title += f"{row['filename']}\n"
            title += f"Wet: {row['pct_wet']:.2f}% | Z-score: {row['z_score']:.2f}"
            if row['flagged']:
                title += " | ⚠ FLAGGED"
            
            ax.set_title(title, fontsize=14, fontweight='bold',
                        color='red' if row['flagged'] else 'black')
            ax.axis('off')
            
            # Add colorbar
            plt.colorbar(im, ax=ax, label='Water (0=Dry, 1=Wet)', fraction=0.046)
            
            plt.tight_layout()
            plt.show()
            
        except Exception as e:
            print(f"Error loading mask: {e}")
    
    def classify(self, classification):
        """Record classification and advance to next mask."""
        row = self.current_df.iloc[self.current_mask_idx]
        
        # Record result
        new_row = {
            'River_Name': self.current_river_name,
            'Filename': row['filename'],
            'Classification': classification,
            'Wet_Pct': row['pct_wet'],
            'Z_Score': row['z_score'],
            'Flagged': row['flagged'],
            'Timestamp': datetime.now().isoformat()
        }
        
        self.qc_results = pd.concat([self.qc_results, pd.DataFrame([new_row])], ignore_index=True)
        
        # Auto-save every 10 classifications
        if len(self.qc_results) % 10 == 0:
            self.save_results()
            print(f"Auto-saved: {len(self.qc_results)} classifications")
        
        # Move to next mask
        self.navigate(1)
    
    def navigate(self, direction):
        """Navigate between masks."""
        self.current_mask_idx = max(0, min(len(self.current_df) - 1, 
                                            self.current_mask_idx + direction))
        self.show_mask()
    
    def finish_river(self):
        """Complete current river and move to next."""
        # Mark river as QC complete
        self.qc_tracking.loc[
            self.qc_tracking['river_name'] == self.current_river_name,
            'qc_complete'
        ] = True
        
        # Count classifications for this river
        river_results = self.qc_results[self.qc_results['River_Name'] == self.current_river_name]
        delete_count = (river_results['Classification'] == 'Delete').sum()
        
        self.qc_tracking.loc[
            self.qc_tracking['river_name'] == self.current_river_name,
            'notes'
        ] = f"{len(river_results)} reviewed, {delete_count} to delete"
        
        # Save progress
        self.save_results()
        self.qc_tracking.to_csv(os.path.join(self.qc_dir, 'QC_tracking.csv'), index=False)
        
        print(f"\n✓ Completed {self.current_river_name}")
        print(f"  Reviewed: {len(river_results)}, To Delete: {delete_count}\n")
        
        # Move to next river
        self.show_river(self.current_river_idx + 1)
    
    def save_results(self):
        """Save QC results to CSV."""
        self.qc_results.to_csv(self.qc_results_path, index=False)
        print(f"  Progress saved: {len(self.qc_results)} total classifications")
    
    def start(self):
        """Display the UI and start QC process."""
        display(self.ui)
        self.show_river(0)
        print("\nQC interface ready!")
        print("Classify each mask as: Good, Delete, or Review")
        print("Use Next River button to complete a river and move to the next\n")

# Usage:
viewer = JupyterMaskQCViewer(
    qc_dir=r"E:\Dissertation\Data\RiverMapping\MaskQC",
    base_mask_dir=r"E:\Dissertation\Data\RiverMapping\RiverMasks"  # Changed mask_dir to base_mask_dir
)
viewer.start()

# %% [markdown]
# ## This actually deletes masks that are both flagged and marked for deletion
# The code first runs a "dry run" to show all masks marked for deletion

# %%
import os
import pandas as pd
from pathlib import Path

def delete_flagged_masks(results_csv, mask_base_dir, dry_run=True):
    """
    Delete mask files that are both flagged (TRUE) and marked for deletion.
    
    Parameters:
    -----------
    results_csv : str
        Path to the mask_qc_results.csv file
    mask_base_dir : str
        Base directory containing river mask folders
    dry_run : bool
        If True, only shows what would be deleted without actually deleting
    """
    
    # Load QC results
    df = pd.read_csv(results_csv)
    
    print(f"Loaded {len(df)} QC records")
    print(f"{'='*60}\n")
    
    # Filter for masks that are both Flagged=TRUE and Classification=Delete
    to_delete = df[(df['Flagged'] == True) & (df['Classification'] == 'Delete')]
    
    print(f"Found {len(to_delete)} masks marked as Flagged AND Delete")
    print(f"{'='*60}\n")
    
    # Track results
    deleted_count = 0
    not_found_count = 0
    error_count = 0
    
    deleted_files = []
    not_found_files = []
    errors = []
    
    # Process each file
    for idx, row in to_delete.iterrows():
        river_name = row['River_Name']
        filename = row['Filename']
        
        # Construct file path
        file_path = os.path.join(mask_base_dir, river_name, "Cleaned", filename)
        
        if os.path.exists(file_path):
            if dry_run:
                print(f"[DRY RUN] Would delete: {river_name}/{filename}")
                deleted_count += 1
                deleted_files.append(f"{river_name}/{filename}")
            else:
                try:
                    os.remove(file_path)
                    print(f"✓ Deleted: {river_name}/{filename}")
                    deleted_count += 1
                    deleted_files.append(f"{river_name}/{filename}")
                except Exception as e:
                    print(f"✗ Error deleting {river_name}/{filename}: {e}")
                    error_count += 1
                    errors.append(f"{river_name}/{filename}: {e}")
        else:
            print(f"⚠ Not found: {river_name}/{filename}")
            not_found_count += 1
            not_found_files.append(f"{river_name}/{filename}")
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    if dry_run:
        print(f"[DRY RUN MODE - No files were actually deleted]")
    print(f"✓ Files deleted (or would be deleted): {deleted_count}")
    print(f"⚠ Files not found: {not_found_count}")
    print(f"✗ Errors encountered: {error_count}")
    
    # Show breakdown by river
    if deleted_count > 0:
        print(f"\n{'='*60}")
        print(f"DELETIONS BY RIVER")
        print(f"{'='*60}")
        river_counts = to_delete[to_delete['Filename'].isin([f.split('/')[-1] for f in deleted_files])]['River_Name'].value_counts()
        for river, count in river_counts.items():
            print(f"  {river}: {count} masks")
    
    # Show not found files if any
    if not_found_count > 0 and not_found_count <= 20:
        print(f"\n{'='*60}")
        print(f"FILES NOT FOUND")
        print(f"{'='*60}")
        for file in not_found_files[:20]:
            print(f"  {file}")
        if not_found_count > 20:
            print(f"  ... and {not_found_count - 20} more")
    
    # Show errors if any
    if error_count > 0:
        print(f"\n{'='*60}")
        print(f"ERRORS")
        print(f"{'='*60}")
        for error in errors:
            print(f"  {error}")
    
    if dry_run:
        print(f"\n{'='*60}")
        print(f"This was a DRY RUN. No files were actually deleted.")
        print(f"Set dry_run=False to actually delete the files.")
        print(f"{'='*60}")

if __name__ == "__main__":
    # Set your paths
    results_csv_path = r"E:\Dissertation\Data\RiverMapping\MaskQC\mask_qc_results.csv"
    mask_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    
    # Run in DRY RUN mode first to see what would be deleted
    print("Running in DRY RUN mode...\n")
    delete_flagged_masks(results_csv_path, mask_directory, dry_run=True)
    
    # Uncomment the lines below to actually delete the files after reviewing the dry run
    print("\n\n" + "="*60)
    print("Running ACTUAL deletion...")
    print("="*60 + "\n")
    delete_flagged_masks(results_csv_path, mask_directory, dry_run=False)

# %% [markdown]
# ## This deletes masks that are not flagged, but marked for deletion and have a wetted area z-score of > 2 or < -2

# %%
import os
import pandas as pd
from pathlib import Path

def delete_unflagged_outliers(results_csv, mask_base_dir, dry_run=True):
    """
    Delete mask files that are NOT flagged but marked for deletion with |z-score| > 2.
    
    Parameters:
    -----------
    results_csv : str
        Path to the mask_qc_results.csv file
    mask_base_dir : str
        Base directory containing river mask folders
    dry_run : bool
        If True, only shows what would be deleted without actually deleting
    """
    
    # Load QC results
    df = pd.read_csv(results_csv)
    
    print(f"Loaded {len(df)} QC records")
    print(f"{'='*60}\n")
    
    # Filter for masks that are:
    # - Flagged = FALSE (not flagged)
    # - Classification = Delete
    # - Z_Score > 2 OR Z_Score < -2
    to_delete = df[
        (df['Flagged'] == False) & 
        (df['Classification'] == 'Delete') &
        ((df['Z_Score'] > 2) | (df['Z_Score'] < -2))
    ]
    
    print(f"Found {len(to_delete)} masks that are:")
    print(f"  - NOT flagged (Flagged = FALSE)")
    print(f"  - Marked for deletion (Classification = Delete)")
    print(f"  - Extreme outliers (|Z-score| > 2)")
    print(f"{'='*60}\n")
    
    # Show Z-score distribution of files to delete
    if len(to_delete) > 0:
        print("Z-score distribution of masks to delete:")
        print(f"  Min Z-score: {to_delete['Z_Score'].min():.2f}")
        print(f"  Max Z-score: {to_delete['Z_Score'].max():.2f}")
        print(f"  Mean Z-score: {to_delete['Z_Score'].mean():.2f}")
        print(f"  Masks with Z > 2: {(to_delete['Z_Score'] > 2).sum()}")
        print(f"  Masks with Z < -2: {(to_delete['Z_Score'] < -2).sum()}")
        print(f"{'='*60}\n")
    
    # Track results
    deleted_count = 0
    not_found_count = 0
    error_count = 0
    
    deleted_files = []
    not_found_files = []
    errors = []
    
    # Process each file
    for idx, row in to_delete.iterrows():
        river_name = row['River_Name']
        filename = row['Filename']
        z_score = row['Z_Score']
        
        # Construct file path
        file_path = os.path.join(mask_base_dir, river_name, "Cleaned", filename)
        
        if os.path.exists(file_path):
            if dry_run:
                print(f"[DRY RUN] Would delete: {river_name}/{filename} (Z={z_score:.2f})")
                deleted_count += 1
                deleted_files.append(f"{river_name}/{filename}")
            else:
                try:
                    os.remove(file_path)
                    print(f"✓ Deleted: {river_name}/{filename} (Z={z_score:.2f})")
                    deleted_count += 1
                    deleted_files.append(f"{river_name}/{filename}")
                except Exception as e:
                    print(f"✗ Error deleting {river_name}/{filename}: {e}")
                    error_count += 1
                    errors.append(f"{river_name}/{filename}: {e}")
        else:
            print(f"⚠ Not found: {river_name}/{filename}")
            not_found_count += 1
            not_found_files.append(f"{river_name}/{filename}")
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    if dry_run:
        print(f"[DRY RUN MODE - No files were actually deleted]")
    print(f"✓ Files deleted (or would be deleted): {deleted_count}")
    print(f"⚠ Files not found: {not_found_count}")
    print(f"✗ Errors encountered: {error_count}")
    
    # Show breakdown by river
    if deleted_count > 0:
        print(f"\n{'='*60}")
        print(f"DELETIONS BY RIVER")
        print(f"{'='*60}")
        river_counts = to_delete[to_delete['Filename'].isin([f.split('/')[-1] for f in deleted_files])]['River_Name'].value_counts()
        for river, count in river_counts.items():
            print(f"  {river}: {count} masks")
    
    # Show not found files if any
    if not_found_count > 0 and not_found_count <= 20:
        print(f"\n{'='*60}")
        print(f"FILES NOT FOUND")
        print(f"{'='*60}")
        for file in not_found_files[:20]:
            print(f"  {file}")
        if not_found_count > 20:
            print(f"  ... and {not_found_count - 20} more")
    
    # Show errors if any
    if error_count > 0:
        print(f"\n{'='*60}")
        print(f"ERRORS")
        print(f"{'='*60}")
        for error in errors:
            print(f"  {error}")
    
    if dry_run:
        print(f"\n{'='*60}")
        print(f"This was a DRY RUN. No files were actually deleted.")
        print(f"Set dry_run=False to actually delete the files.")
        print(f"{'='*60}")

if __name__ == "__main__":
    # Set your paths
    results_csv_path = r"E:\Dissertation\Data\RiverMapping\MaskQC\mask_qc_results.csv"
    mask_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    
    # Run in DRY RUN mode first to see what would be deleted
    print("Running in DRY RUN mode...\n")
    delete_unflagged_outliers(results_csv_path, mask_directory, dry_run=True)
    
    # Uncomment the lines below to actually delete the files after reviewing the dry run
    print("\n\n" + "="*60)
    print("Running ACTUAL deletion...")
    print("="*60 + "\n")
    delete_unflagged_outliers(results_csv_path, mask_directory, dry_run=False)

# %% [markdown]
# ## Prints out the river reaches with less than 20 masks remaining

# %%
import os
import pandas as pd

def count_remaining_masks(mask_base_dir, output_csv=None):
    """
    Count remaining .tif mask files for each river and identify rivers with < 20 masks.
    
    Parameters:
    -----------
    mask_base_dir : str
        Base directory containing river mask folders
    output_csv : str, optional
        If provided, save the results to this CSV file
    """
    
    # Get all river directories
    river_dirs = [d for d in os.listdir(mask_base_dir) 
                  if os.path.isdir(os.path.join(mask_base_dir, d))]
    river_dirs = sorted(river_dirs)
    
    print(f"Scanning {len(river_dirs)} river directories...\n")
    print(f"{'='*60}")
    
    # Track counts
    mask_counts = []
    
    for river_name in river_dirs:
        # Path to Cleaned folder
        cleaned_dir = os.path.join(mask_base_dir, river_name, "Cleaned")
        
        if os.path.exists(cleaned_dir):
            # Count .tif files
            tif_files = [f for f in os.listdir(cleaned_dir) 
                        if f.lower().endswith('.tif')]
            count = len(tif_files)
        else:
            count = 0
        
        mask_counts.append({
            'River_Name': river_name,
            'Mask_Count': count
        })
        
        print(f"{river_name}: {count} masks")
    
    # Convert to DataFrame
    df = pd.DataFrame(mask_counts)
    
    # Print summary statistics
    print(f"\n{'='*60}")
    print(f"SUMMARY STATISTICS")
    print(f"{'='*60}")
    print(f"Total rivers: {len(df)}")
    print(f"Total masks: {df['Mask_Count'].sum()}")
    print(f"Mean masks per river: {df['Mask_Count'].mean():.1f}")
    print(f"Median masks per river: {df['Mask_Count'].median():.1f}")
    print(f"Min masks: {df['Mask_Count'].min()}")
    print(f"Max masks: {df['Mask_Count'].max()}")
    
    # Rivers with < 20 masks
    low_count_rivers = df[df['Mask_Count'] < 20].sort_values('Mask_Count')
    
    print(f"\n{'='*60}")
    print(f"RIVERS WITH < 20 MASKS ({len(low_count_rivers)} rivers)")
    print(f"{'='*60}")
    
    if len(low_count_rivers) > 0:
        for idx, row in low_count_rivers.iterrows():
            print(f"{row['River_Name']}: {row['Mask_Count']} masks")
    else:
        print("No rivers with < 20 masks")
    
    # Rivers with 0 masks
    zero_count_rivers = df[df['Mask_Count'] == 0]
    
    if len(zero_count_rivers) > 0:
        print(f"\n{'='*60}")
        print(f"RIVERS WITH 0 MASKS ({len(zero_count_rivers)} rivers)")
        print(f"{'='*60}")
        for idx, row in zero_count_rivers.iterrows():
            print(f"  {row['River_Name']}")
    
    # Distribution by mask count ranges
    print(f"\n{'='*60}")
    print(f"DISTRIBUTION BY MASK COUNT")
    print(f"{'='*60}")
    print(f"0 masks: {(df['Mask_Count'] == 0).sum()} rivers")
    print(f"1-10 masks: {((df['Mask_Count'] >= 1) & (df['Mask_Count'] <= 10)).sum()} rivers")
    print(f"11-20 masks: {((df['Mask_Count'] >= 11) & (df['Mask_Count'] <= 20)).sum()} rivers")
    print(f"21-30 masks: {((df['Mask_Count'] >= 21) & (df['Mask_Count'] <= 30)).sum()} rivers")
    print(f"31-40 masks: {((df['Mask_Count'] >= 31) & (df['Mask_Count'] <= 40)).sum()} rivers")
    print(f"41+ masks: {(df['Mask_Count'] > 40).sum()} rivers")
    
    # Save to CSV if requested
    if output_csv:
        df.to_csv(output_csv, index=False)
        print(f"\n{'='*60}")
        print(f"Results saved to: {output_csv}")
    
    return df

if __name__ == "__main__":
    # Set your paths
    mask_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    output_file = r"E:\Dissertation\Data\RiverMapping\MaskQC\remaining_masks_count.csv"
    
    # Run the count
    df = count_remaining_masks(mask_directory, output_csv=output_file)

# %% [markdown]
# ## This returns unique pixel values for all masks (should be 1s and 0s only)

# %%
import os
import numpy as np
import rasterio
import warnings
from collections import defaultdict

def check_mask_pixel_values(mask_base_dir):
    """
    Check one mask file per river for pixel values. Should only contain 0 and 1 (or 0 and 255).
    Flag any masks with unexpected values.
    
    Parameters:
    -----------
    mask_base_dir : str
        Base directory containing river mask folders
        
    Returns:
    --------
    dict
        Dictionary with all unique values found across sampled masks
    """
    
    # Get all river directories
    river_dirs = [d for d in os.listdir(mask_base_dir) 
                  if os.path.isdir(os.path.join(mask_base_dir, d))]
    river_dirs = sorted(river_dirs)
    
    print(f"Checking one mask from each of {len(river_dirs)} rivers...\n")
    print(f"{'='*60}\n")
    
    # Track unique values across all masks
    all_unique_values = set()
    
    # Track problematic masks
    problematic_masks = []
    
    # Track value encoding types
    encoding_types = defaultdict(int)  # 0/1 vs 0/255
    
    # Counters
    rivers_checked = 0
    rivers_skipped = 0
    errors = 0
    
    for river_name in river_dirs:
        # Path to Cleaned folder
        cleaned_dir = os.path.join(mask_base_dir, river_name, "Cleaned")
        
        if not os.path.exists(cleaned_dir):
            rivers_skipped += 1
            continue
        
        # Get all .tif files
        tif_files = [f for f in os.listdir(cleaned_dir) 
                    if f.lower().endswith('.tif')]
        
        if len(tif_files) == 0:
            rivers_skipped += 1
            continue
        
        # Check only the first mask file
        tif_file = tif_files[0]
        file_path = os.path.join(cleaned_dir, tif_file)
        
        try:
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
                with rasterio.open(file_path) as src:
                    data = src.read(1)
            
            # Get unique values
            unique_vals = np.unique(data)
            
            # Add to overall set
            for val in unique_vals:
                all_unique_values.add(val)
            
            # Check if values are expected
            unique_set = set(unique_vals)
            
            # Determine encoding type
            if unique_set <= {0, 1}:
                encoding_types['0/1'] += 1
                print(f"✓ {river_name}: 0/1 encoding")
            elif unique_set <= {0, 255}:
                encoding_types['0/255'] += 1
                print(f"✓ {river_name}: 0/255 encoding")
            else:
                # Unexpected values found
                problematic_masks.append({
                    'river': river_name,
                    'filename': tif_file,
                    'unique_values': sorted(unique_vals.tolist())
                })
                print(f"⚠ FLAGGED: {river_name}/{tif_file}")
                print(f"   Unexpected values: {sorted(unique_vals.tolist())}\n")
            
            rivers_checked += 1
            
        except Exception as e:
            errors += 1
            print(f"✗ Error reading {river_name}/{tif_file}: {e}")
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"Total rivers: {len(river_dirs)}")
    print(f"Rivers checked: {rivers_checked}")
    print(f"Rivers skipped (no masks): {rivers_skipped}")
    print(f"Errors encountered: {errors}")
    print(f"\nUnique pixel values found across sampled masks:")
    print(f"  {sorted(all_unique_values)}")
    
    print(f"\nEncoding types:")
    print(f"  0/1 encoding: {encoding_types['0/1']} rivers")
    print(f"  0/255 encoding: {encoding_types['0/255']} rivers")
    
    print(f"\n{'='*60}")
    print(f"PROBLEMATIC MASKS")
    print(f"{'='*60}")
    print(f"Rivers with unexpected values: {len(problematic_masks)}")
    
    if len(problematic_masks) == 0:
        print("✓ All sampled masks contain only expected values (0/1 or 0/255)")
    else:
        print(f"\n{len(problematic_masks)} rivers have unexpected pixel values:")
        for mask in problematic_masks:
            print(f"\n  {mask['river']}/{mask['filename']}")
            print(f"    Values: {mask['unique_values']}")
    
    # Return results
    return {
        'all_unique_values': sorted(all_unique_values),
        'problematic_masks': problematic_masks,
        'encoding_types': dict(encoding_types),
        'rivers_checked': rivers_checked,
        'rivers_skipped': rivers_skipped,
        'errors': errors
    }

if __name__ == "__main__":
    # Set your path
    mask_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    
    # Run the check
    results = check_mask_pixel_values(mask_directory)
    
    # Print final verdict
    print(f"\n{'='*60}")
    print(f"FINAL VERDICT")
    print(f"{'='*60}")
    if len(results['problematic_masks']) == 0:
        print("✓ ALL MASKS PASSED: Only binary values (0/1 or 0/255) found")
    else:
        print(f"⚠ {len(results['problematic_masks'])} MASKS FLAGGED with unexpected values")
        print("Review the problematic masks listed above")

# %% [markdown]
# ## This reformats Feifei's river masks to be compatible with RivMapper mobility scripts

# %%
"""
Reformat River Masks for Mobility/SedStorage Calculator

This script reformats existing river masks to make them compatible with the 
mobility sedstorage modeling workflow by:
1. Extracting geographic bounds from reach shapefiles
2. Assigning EPSG:4326 CRS and proper geotransform
3. Converting pixel values (255→1, 0→0)
4. Renaming to required pattern: {river_name}_reach_1_{year}_DSWE_level_2_cleaned.tif
5. Reorganizing directory structure with reach_1 subfolder

Author: James (Huck) Rees
Date: January 30, 2026
"""

import os
import re
import shutil
import numpy as np
import rasterio
from rasterio.transform import from_bounds
import geopandas as gpd
from pathlib import Path


def extract_year_from_filename(filename):
    """
    Extract the first 4-digit year from filename.
    
    Examples:
        'Amur_Komsomolsk_2020_01_01_2020_12_31_mask_thresh.tif' -> 2020
        'River_2015_mask.tif' -> 2015
    
    Parameters:
    -----------
    filename : str
        Input filename
        
    Returns:
    --------
    int or None
        First year found, or None if no year found
    """
    pattern = r'(\d{4})'
    match = re.search(pattern, filename)
    if match:
        year = int(match.group(1))
        # Sanity check: reasonable year range for Landsat data
        if 1984 <= year <= 2030:
            return year
    return None


def get_shapefile_bounds(shapefile_path):
    """
    Extract geographic bounds from reach shapefile.
    
    Parameters:
    -----------
    shapefile_path : str
        Path to reach boundary shapefile
        
    Returns:
    --------
    tuple
        (minx, miny, maxx, maxy) in EPSG:4326 coordinates
    """
    gdf = gpd.read_file(shapefile_path)
    
    # Reproject to EPSG:4326 if needed
    if gdf.crs.to_epsg() != 4326:
        gdf = gdf.to_crs(epsg=4326)
    
    # Get total bounds
    bounds = gdf.total_bounds  # (minx, miny, maxx, maxy)
    
    return tuple(bounds)


def convert_pixel_values(data):
    """
    Convert pixel values to binary format expected by mobility calculator.
    
    Parameters:
    -----------
    data : numpy.ndarray
        Input raster data
        
    Returns:
    --------
    numpy.ndarray
        Binary raster with 1 for water, 0 for non-water
    """
    # Create output array
    output = np.zeros_like(data, dtype=np.uint8)
    
    # Convert 255 to 1, everything else to 0
    output[data == 255] = 1
    
    return output


def reformat_mask(input_path, output_path, bounds, river_name, year, 
                  dswe_level=2, dry_run=False):
    """
    Reformat a single mask file with proper georeferencing and naming.
    
    Parameters:
    -----------
    input_path : str
        Path to input mask file
    output_path : str
        Path where reformatted mask will be saved
    bounds : tuple
        Geographic bounds (minx, miny, maxx, maxy) in EPSG:4326
    river_name : str
        Name of the river
    year : int
        Year to use in filename
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    bool
        True if successful, False otherwise
    """
    try:
        if dry_run:
            print(f"  [DRY RUN] Would reformat: {os.path.basename(input_path)}")
            print(f"            -> {os.path.basename(output_path)}")
            return True
        
        # Read input raster
        with rasterio.open(input_path) as src:
            data = src.read(1)
            height, width = data.shape
        
        # Convert pixel values
        binary_data = convert_pixel_values(data)
        
        # Calculate geotransform from bounds
        minx, miny, maxx, maxy = bounds
        transform = from_bounds(minx, miny, maxx, maxy, width, height)
        
        # Create output directory if needed
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # Define EPSG:4326 as WKT to avoid PROJ database issues
        wgs84_wkt = """GEOGCS["WGS 84",
            DATUM["WGS_1984",
                SPHEROID["WGS 84",6378137,298.257223563,
                    AUTHORITY["EPSG","7030"]],
                AUTHORITY["EPSG","6326"]],
            PRIMEM["Greenwich",0,
                AUTHORITY["EPSG","8901"]],
            UNIT["degree",0.0174532925199433,
                AUTHORITY["EPSG","9122"]],
            AUTHORITY["EPSG","4326"]]"""
        
        # Write reformatted raster
        with rasterio.open(
            output_path,
            'w',
            driver='GTiff',
            height=height,
            width=width,
            count=1,
            dtype=rasterio.uint8,
            crs=wgs84_wkt,
            transform=transform,
            compress='lzw'
        ) as dst:
            dst.write(binary_data, 1)
        
        return True
        
    except Exception as e:
        print(f"  ERROR reformatting {os.path.basename(input_path)}: {e}")
        return False


def process_river(working_directory, river_name, dswe_level=2, dry_run=False):
    """
    Process all masks for a single river.
    
    Parameters:
    -----------
    working_directory : str
        Base working directory
    river_name : str
        Name of the river to process
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    dict
        Summary statistics for this river
    """
    print(f"\n{'='*60}")
    print(f"Processing: {river_name}")
    print(f"{'='*60}")
    
    # Define paths
    shapefile_path = os.path.join(working_directory, 'RiverMapping', 'Reaches', 
                                  river_name, f'{river_name}.shp')
    masks_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                             river_name, 'Cleaned')
    output_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                              river_name, 'reach_1', 'Cleaned')
    
    # Initialize statistics
    stats = {
        'river_name': river_name,
        'total_masks': 0,
        'successful': 0,
        'failed': 0,
        'skipped': 0
    }
    
    # Check if shapefile exists
    if not os.path.exists(shapefile_path):
        print(f"ERROR: Shapefile not found: {shapefile_path}")
        return stats
    
    # Check if masks directory exists
    if not os.path.exists(masks_dir):
        print(f"ERROR: Masks directory not found: {masks_dir}")
        return stats
    
    # Get shapefile bounds
    try:
        bounds = get_shapefile_bounds(shapefile_path)
        print(f"Shapefile bounds: {bounds}")
    except Exception as e:
        print(f"ERROR reading shapefile: {e}")
        return stats
    
    # Get list of mask files
    mask_files = [f for f in os.listdir(masks_dir) if f.endswith('.tif')]
    stats['total_masks'] = len(mask_files)
    
    if stats['total_masks'] == 0:
        print("WARNING: No .tif files found in Cleaned directory")
        return stats
    
    print(f"Found {stats['total_masks']} mask files to process")
    
    # Process each mask
    for i, mask_file in enumerate(mask_files, 1):
        input_path = os.path.join(masks_dir, mask_file)
        
        # Extract year from filename
        year = extract_year_from_filename(mask_file)
        if year is None:
            print(f"  [{i}/{stats['total_masks']}] WARNING: Could not extract year from {mask_file} - skipping")
            stats['skipped'] += 1
            continue
        
        # Generate output filename
        output_filename = f"{river_name}_reach_1_{year}_DSWE_level_{dswe_level}_cleaned.tif"
        output_path = os.path.join(output_dir, output_filename)
        
        # Reformat mask
        print(f"  [{i}/{stats['total_masks']}] Processing {mask_file} (year={year})")
        success = reformat_mask(input_path, output_path, bounds, river_name, 
                               year, dswe_level, dry_run)
        
        if success:
            stats['successful'] += 1
        else:
            stats['failed'] += 1
    
    # Print summary
    print(f"\nSummary for {river_name}:")
    print(f"  Total masks: {stats['total_masks']}")
    print(f"  Successful: {stats['successful']}")
    print(f"  Failed: {stats['failed']}")
    print(f"  Skipped: {stats['skipped']}")
    
    # Move original Cleaned folder if successful and not dry run
    if stats['successful'] > 0 and not dry_run:
        backup_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                                  river_name, 'Cleaned_original')
        try:
            print(f"\nBacking up original Cleaned folder to: Cleaned_original")
            if os.path.exists(backup_dir):
                shutil.rmtree(backup_dir)
            shutil.move(masks_dir, backup_dir)
            print("  Original masks backed up successfully")
        except Exception as e:
            print(f"  WARNING: Could not backup original Cleaned folder: {e}")
    
    return stats


def process_multiple_rivers(working_directory, river_names, dswe_level=2, dry_run=False):
    """
    Process multiple rivers.
    
    Parameters:
    -----------
    working_directory : str
        Base working directory
    river_names : list
        List of river names to process
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    list
        List of summary statistics dictionaries
    """
    all_stats = []
    
    for river_name in river_names:
        stats = process_river(working_directory, river_name, dswe_level, dry_run)
        all_stats.append(stats)
    
    # Print overall summary
    print(f"\n{'='*60}")
    print("OVERALL SUMMARY")
    print(f"{'='*60}")
    print(f"Rivers processed: {len(river_names)}")
    
    total_masks = sum(s['total_masks'] for s in all_stats)
    total_successful = sum(s['successful'] for s in all_stats)
    total_failed = sum(s['failed'] for s in all_stats)
    total_skipped = sum(s['skipped'] for s in all_stats)
    
    print(f"Total masks: {total_masks}")
    print(f"Successful: {total_successful}")
    print(f"Failed: {total_failed}")
    print(f"Skipped: {total_skipped}")
    
    if dry_run:
        print("\n*** DRY RUN MODE - No files were actually modified ***")
    
    return all_stats


# Example usage
if __name__ == "__main__":
    
    # Configuration
    working_directory = r"D:\Dissertation\Data"  # Update this to your working directory
    
    # Option 1: Process a single river
    #river_name = "Amur_Komsomolsk"
    #process_river(working_directory, river_name, dswe_level=2, dry_run=False)
    
    # Option 2: Process all rivers from CSV
    import pandas as pd
    df = pd.read_csv(r"D:\Dissertation\Data\Zhaoetal2025_river_datasheet.csv")
    river_names = df['river_name'].tolist()
    process_multiple_rivers(working_directory, river_names, dswe_level=2, dry_run=False)

# %% [markdown]
# ## This reformats Evans's river masks to be compatible with RivMapper mobility scripts

# %%
"""
Reformat River Masks for Mobility/SedStorage Calculator

This script reformats existing river masks to make them compatible with the 
mobility sedstorage modeling workflow. Handles two input formats:

FORMAT 1: Masks with no CRS (e.g., Greenberg et al. 2024)
- Pixel values: 0 and 255 (converted to 0 and 1)
- No georeferencing
- Assigns EPSG:4326 using shapefile bounds

FORMAT 2: Masks with existing CRS (e.g., UTM projected)
- Pixel values: 0 and 1 (already correct)
- Already georeferenced in UTM or other projection
- Reprojects to EPSG:4326

Both formats are processed to:
1. Extract geographic bounds from reach shapefiles
2. Ensure EPSG:4326 CRS (assign or reproject as needed)
3. Convert pixel values to binary 0/1 format if needed
4. Rename to required pattern: {river_name}_reach_1_{year}_DSWE_level_2_cleaned.tif
5. Reorganize directory structure with reach_1 subfolder

Author: James (Huck) Rees
Date: January 30, 2026
"""

import os
import re
import shutil
import numpy as np
import rasterio
from rasterio.transform import from_bounds
from rasterio.warp import calculate_default_transform, reproject, Resampling
import geopandas as gpd
from pathlib import Path


def extract_year_from_filename(filename):
    """
    Extract the first 4-digit year from filename.
    
    Examples:
        'Amur_Komsomolsk_2020_01_01_2020_12_31_mask_thresh.tif' -> 2020
        'White_Petersburg_1995_01-01_12-31_mask.tif' -> 1995
        'River_2015_mask.tif' -> 2015
    
    Parameters:
    -----------
    filename : str
        Input filename
        
    Returns:
    --------
    int or None
        First year found, or None if no year found
    """
    # Match 4-digit year with underscores or hyphens around it
    pattern = r'(\d{4})'
    match = re.search(pattern, filename)
    if match:
        year = int(match.group(1))
        # Sanity check: reasonable year range for Landsat data
        if 1984 <= year <= 2030:
            return year
    return None


def get_shapefile_bounds(shapefile_path):
    """
    Extract geographic bounds from reach shapefile.
    
    Parameters:
    -----------
    shapefile_path : str
        Path to reach boundary shapefile
        
    Returns:
    --------
    tuple
        (minx, miny, maxx, maxy) in EPSG:4326 coordinates
    """
    gdf = gpd.read_file(shapefile_path)
    
    # Reproject to EPSG:4326 if needed
    if gdf.crs.to_epsg() != 4326:
        gdf = gdf.to_crs(epsg=4326)
    
    # Get total bounds
    bounds = gdf.total_bounds  # (minx, miny, maxx, maxy)
    
    return tuple(bounds)


def detect_pixel_format(data):
    """
    Detect whether pixels are in 0/255 format or 0/1 format.
    
    Parameters:
    -----------
    data : numpy.ndarray
        Input raster data
        
    Returns:
    --------
    str
        'binary' if already 0/1, 'scaled' if 0/255, 'unknown' otherwise
    """
    unique_values = np.unique(data)
    
    # Check if already binary (0 and 1 only)
    if set(unique_values).issubset({0, 1}):
        return 'binary'
    
    # Check if scaled format (0 and 255)
    if set(unique_values).issubset({0, 255}):
        return 'scaled'
    
    return 'unknown'


def convert_pixel_values(data):
    """
    Convert pixel values to binary format expected by mobility calculator.
    Automatically detects format and converts if needed.
    
    Parameters:
    -----------
    data : numpy.ndarray
        Input raster data
        
    Returns:
    --------
    numpy.ndarray
        Binary raster with 1 for water, 0 for non-water
    """
    pixel_format = detect_pixel_format(data)
    
    if pixel_format == 'binary':
        # Already in correct format
        return data.astype(np.uint8)
    
    elif pixel_format == 'scaled':
        # Create output array
        output = np.zeros_like(data, dtype=np.uint8)
        # Convert 255 to 1, everything else to 0
        output[data == 255] = 1
        return output
    
    else:
        # Unknown format - try to handle gracefully
        print(f"  WARNING: Unknown pixel format detected. Unique values: {np.unique(data)}")
        # Assume any non-zero value is water
        output = np.zeros_like(data, dtype=np.uint8)
        output[data > 0] = 1
        return output


def reformat_mask(input_path, output_path, bounds, river_name, year, 
                  dswe_level=2, dry_run=False):
    """
    Reformat a single mask file with proper georeferencing and naming.
    Handles two cases:
    1. Masks with no CRS - assigns EPSG:4326 using shapefile bounds
    2. Masks with existing CRS - reprojects to EPSG:4326
    
    Parameters:
    -----------
    input_path : str
        Path to input mask file
    output_path : str
        Path where reformatted mask will be saved
    bounds : tuple
        Geographic bounds (minx, miny, maxx, maxy) in EPSG:4326
    river_name : str
        Name of the river
    year : int
        Year to use in filename
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    bool
        True if successful, False otherwise
    """
    try:
        if dry_run:
            print(f"  [DRY RUN] Would reformat: {os.path.basename(input_path)}")
            print(f"            -> {os.path.basename(output_path)}")
            return True
        
        # Read input raster
        with rasterio.open(input_path) as src:
            data = src.read(1)
            src_crs = src.crs
            src_transform = src.transform
            src_bounds = src.bounds
            height, width = data.shape
        
        # Convert pixel values (handles both 0/1 and 0/255 formats)
        binary_data = convert_pixel_values(data)
        
        # Define EPSG:4326 as WKT to avoid PROJ database issues
        wgs84_wkt = """GEOGCS["WGS 84",
            DATUM["WGS_1984",
                SPHEROID["WGS 84",6378137,298.257223563,
                    AUTHORITY["EPSG","7030"]],
                AUTHORITY["EPSG","6326"]],
            PRIMEM["Greenwich",0,
                AUTHORITY["EPSG","8901"]],
            UNIT["degree",0.0174532925199433,
                AUTHORITY["EPSG","9122"]],
            AUTHORITY["EPSG","4326"]]"""
        
        # Create output directory if needed
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # Handle two cases: no CRS vs existing CRS
        if src_crs is None:
            # Case 1: No CRS - assign EPSG:4326 using shapefile bounds
            print(f"    No CRS detected - assigning EPSG:4326 with shapefile bounds")
            minx, miny, maxx, maxy = bounds
            transform = from_bounds(minx, miny, maxx, maxy, width, height)
            output_data = binary_data
            output_height, output_width = height, width
            
        else:
            # Case 2: Has CRS - reproject to EPSG:4326
            print(f"    Reprojecting from {src_crs} to EPSG:4326")
            
            # Calculate destination transform and dimensions
            dst_transform, dst_width, dst_height = calculate_default_transform(
                src_crs,
                wgs84_wkt,
                width,
                height,
                *src_bounds
            )
            
            # Create destination array
            output_data = np.zeros((dst_height, dst_width), dtype=np.uint8)
            
            # Reproject
            reproject(
                source=binary_data,
                destination=output_data,
                src_transform=src_transform,
                src_crs=src_crs,
                dst_transform=dst_transform,
                dst_crs=wgs84_wkt,
                resampling=Resampling.nearest
            )
            
            transform = dst_transform
            output_height, output_width = dst_height, dst_width
        
        # Write reformatted raster
        with rasterio.open(
            output_path,
            'w',
            driver='GTiff',
            height=output_height,
            width=output_width,
            count=1,
            dtype=rasterio.uint8,
            crs=wgs84_wkt,
            transform=transform,
            compress='lzw'
        ) as dst:
            dst.write(output_data, 1)
        
        return True
        
    except Exception as e:
        print(f"  ERROR reformatting {os.path.basename(input_path)}: {e}")
        return False


def process_river(working_directory, river_name, dswe_level=2, dry_run=False):
    """
    Process all masks for a single river.
    
    Parameters:
    -----------
    working_directory : str
        Base working directory
    river_name : str
        Name of the river to process
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    dict
        Summary statistics for this river
    """
    print(f"\n{'='*60}")
    print(f"Processing: {river_name}")
    print(f"{'='*60}")
    
    # Define paths
    shapefile_path = os.path.join(working_directory, 'RiverMapping', 'Reaches', 
                                  river_name, f'{river_name}.shp')
    masks_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                             river_name, 'Cleaned')
    output_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                              river_name, 'reach_1', 'Cleaned')
    
    # Initialize statistics
    stats = {
        'river_name': river_name,
        'total_masks': 0,
        'successful': 0,
        'failed': 0,
        'skipped': 0
    }
    
    # Check if shapefile exists
    if not os.path.exists(shapefile_path):
        print(f"ERROR: Shapefile not found: {shapefile_path}")
        return stats
    
    # Check if masks directory exists
    if not os.path.exists(masks_dir):
        print(f"ERROR: Masks directory not found: {masks_dir}")
        return stats
    
    # Get shapefile bounds
    try:
        bounds = get_shapefile_bounds(shapefile_path)
        print(f"Shapefile bounds: {bounds}")
    except Exception as e:
        print(f"ERROR reading shapefile: {e}")
        return stats
    
    # Get list of mask files
    mask_files = [f for f in os.listdir(masks_dir) if f.endswith('.tif')]
    stats['total_masks'] = len(mask_files)
    
    if stats['total_masks'] == 0:
        print("WARNING: No .tif files found in Cleaned directory")
        return stats
    
    print(f"Found {stats['total_masks']} mask files to process")
    
    # Process each mask
    for i, mask_file in enumerate(mask_files, 1):
        input_path = os.path.join(masks_dir, mask_file)
        
        # Extract year from filename
        year = extract_year_from_filename(mask_file)
        if year is None:
            print(f"  [{i}/{stats['total_masks']}] WARNING: Could not extract year from {mask_file} - skipping")
            stats['skipped'] += 1
            continue
        
        # Generate output filename
        output_filename = f"{river_name}_reach_1_{year}_DSWE_level_{dswe_level}_cleaned.tif"
        output_path = os.path.join(output_dir, output_filename)
        
        # Reformat mask
        print(f"  [{i}/{stats['total_masks']}] Processing {mask_file} (year={year})")
        success = reformat_mask(input_path, output_path, bounds, river_name, 
                               year, dswe_level, dry_run)
        
        if success:
            stats['successful'] += 1
        else:
            stats['failed'] += 1
    
    # Print summary
    print(f"\nSummary for {river_name}:")
    print(f"  Total masks: {stats['total_masks']}")
    print(f"  Successful: {stats['successful']}")
    print(f"  Failed: {stats['failed']}")
    print(f"  Skipped: {stats['skipped']}")
    
    # Move original Cleaned folder if successful and not dry run
    if stats['successful'] > 0 and not dry_run:
        backup_dir = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                                  river_name, 'Cleaned_original')
        try:
            print(f"\nBacking up original Cleaned folder to: Cleaned_original")
            if os.path.exists(backup_dir):
                shutil.rmtree(backup_dir)
            shutil.move(masks_dir, backup_dir)
            print("  Original masks backed up successfully")
        except Exception as e:
            print(f"  WARNING: Could not backup original Cleaned folder: {e}")
    
    return stats


def process_multiple_rivers(working_directory, river_names, dswe_level=2, dry_run=False):
    """
    Process multiple rivers.
    
    Parameters:
    -----------
    working_directory : str
        Base working directory
    river_names : list
        List of river names to process
    dswe_level : int, optional
        DSWE level to assign (default: 2)
    dry_run : bool, optional
        If True, only print actions without executing (default: False)
        
    Returns:
    --------
    list
        List of summary statistics dictionaries
    """
    all_stats = []
    
    for river_name in river_names:
        stats = process_river(working_directory, river_name, dswe_level, dry_run)
        all_stats.append(stats)
    
    # Print overall summary
    print(f"\n{'='*60}")
    print("OVERALL SUMMARY")
    print(f"{'='*60}")
    print(f"Rivers processed: {len(river_names)}")
    
    total_masks = sum(s['total_masks'] for s in all_stats)
    total_successful = sum(s['successful'] for s in all_stats)
    total_failed = sum(s['failed'] for s in all_stats)
    total_skipped = sum(s['skipped'] for s in all_stats)
    
    print(f"Total masks: {total_masks}")
    print(f"Successful: {total_successful}")
    print(f"Failed: {total_failed}")
    print(f"Skipped: {total_skipped}")
    
    if dry_run:
        print("\n*** DRY RUN MODE - No files were actually modified ***")
    
    return all_stats


# Example usage
if __name__ == "__main__":
    
    # Configuration
    working_directory = r"E:\Dissertation\Data"  # Update this to your working directory
    
    # Option 1: Process a single river
    # Example with no-CRS masks (Greenberg et al. 2024 format):
    #river_name = "Amur_Komsomolsk"
    # Example with UTM masks (needs reprojection):
    # river_name = "White_Petersburg"
    
    #process_river(working_directory, river_name, dswe_level=2, dry_run=True)
    
    # Option 2: Process multiple rivers (works with mixed formats)
    # river_names = [
    #     "Amur_Komsomolsk",      # No CRS - will assign EPSG:4326
    #     "White_Petersburg",      # UTM - will reproject to EPSG:4326
    #     "Bhareli_NTRoadCrossing"
    # ]
    # process_multiple_rivers(working_directory, river_names, dswe_level=2, dry_run=True)
    
    # Option 3: Process all rivers from CSV
    import pandas as pd
    df = pd.read_csv(r"E:\Dissertation\Data\Greenbergetal2024_river_datasheet.csv")
    river_names = df['river_name'].tolist()
    process_multiple_rivers(working_directory, river_names, dswe_level=2, dry_run=False)

# %% [markdown]
# ## This is an additional river mask QC viewing script to catch "stragglers" - bad masks that made it past previous QC efforts

# %%
"""
Interactive Mask Grid QA/QC Tool

This script provides an interactive interface for reviewing water masks across ALL rivers
in the RiverMasks directory. Users can click masks to flag them for deletion, navigate 
between rivers, and export a summary CSV of all flagged masks.

Features:
- Automatically loads all rivers from RiverMasks directory
- Grid display of all masks for each river (from reach_1/Cleaned)
- Click to toggle deletion flag (red border)
- Navigation: Previous River, Skip River, Next River
- Select All / Deselect All buttons
- Outputs single CSV with all flagged masks from all rivers

Performance Optimizations:
- Masks are downsampled to 300x300 thumbnails for display (90% memory reduction)
- Uses matplotlib's native colormap instead of RGB arrays
- Full resolution data preserved - only display is downsampled

Author: James (Huck) Rees
Date: January 30, 2026
"""

# %matplotlib qt
import os
import re
import numpy as np
import pandas as pd
import rasterio
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.widgets import Button
from natsort import natsorted
from pathlib import Path
from scipy.ndimage import zoom


class MaskGridQC:
    """
    Interactive QA/QC tool for reviewing water masks across all rivers.
    """
    
    def __init__(self, working_directory):
        """
        Initialize the QA/QC tool.
        
        Parameters:
        -----------
        working_directory : str
            Base working directory
        """
        self.working_directory = working_directory
        self.base_path = os.path.join(working_directory, 'RiverMapping', 'RiverMasks')
        
        # Load all rivers
        self.rivers = self._load_rivers()
        self.current_river_idx = 0
        
        # Store selections: {(river_name, year, filename): True/False}
        self.selections = {}
        
        # Current river data
        self.current_river_name = None
        self.current_masks = []
        self.current_years = []
        self.current_filenames = []
        
        # Matplotlib objects
        self.fig = None
        self.axes = []
        self.borders = []
        
        # Button widgets
        self.btn_prev = None
        self.btn_skip = None
        self.btn_next = None
        self.btn_select_all = None
        self.btn_deselect_all = None
        self.btn_finish = None
        
    def _load_rivers(self):
        """
        Find all river directories with reach_1/Cleaned structure.
        
        Returns:
        --------
        list
            List of river names, sorted alphabetically
        """
        rivers = []
        
        if not os.path.exists(self.base_path):
            print(f"ERROR: RiverMasks directory not found: {self.base_path}")
            return rivers
        
        # Find all river directories with reach_1/Cleaned
        for item in os.listdir(self.base_path):
            item_path = os.path.join(self.base_path, item)
            if os.path.isdir(item_path):
                # Check for reach_1/Cleaned structure
                cleaned_path = os.path.join(item_path, 'reach_1', 'Cleaned')
                if os.path.exists(cleaned_path):
                    # Check if there are any .tif files
                    tif_files = [f for f in os.listdir(cleaned_path) if f.endswith('.tif')]
                    if len(tif_files) > 0:
                        rivers.append(item)
        
        # Sort alphabetically
        rivers.sort()
        
        return rivers
    
    def _extract_year_from_filename(self, filename):
        """
        Extract year from filename.
        
        Parameters:
        -----------
        filename : str
            Mask filename
            
        Returns:
        --------
        int or None
            Year if found, None otherwise
        """
        # Pattern: {river_name}_reach_{N}_{YEAR}_DSWE_level_{N}_cleaned.tif
        pattern = r'_reach_\d+_(\d{4})_DSWE'
        match = re.search(pattern, filename)
        if match:
            return int(match.group(1))
        return None
    
    def _load_masks_for_river(self, river_idx):
        """
        Load all masks for a given river (from reach_1/Cleaned).
        
        Parameters:
        -----------
        river_idx : int
            Index in self.rivers list
            
        Returns:
        --------
        tuple
            (river_name, masks, years, filenames) - loaded data
        """
        if river_idx < 0 or river_idx >= len(self.rivers):
            return None, [], [], []
        
        river_name = self.rivers[river_idx]
        river_path = os.path.join(self.base_path, river_name, 'reach_1', 'Cleaned')
        
        # Get all .tif files
        tif_files = [f for f in os.listdir(river_path) if f.endswith('.tif')]
        tif_files = natsorted(tif_files)
        
        print(f"Loading {len(tif_files)} masks for {river_name}...", end=' ', flush=True)
        
        masks = []
        years = []
        filenames = []
        
        for tif_file in tif_files:
            filepath = os.path.join(river_path, tif_file)
            year = self._extract_year_from_filename(tif_file)
            
            if year is None:
                print(f"\nWARNING: Could not extract year from {tif_file}")
                continue
            
            try:
                with rasterio.open(filepath) as src:
                    data = src.read(1)
                    masks.append(data)
                    years.append(year)
                    filenames.append(tif_file)
            except Exception as e:
                print(f"\nERROR loading {tif_file}: {e}")
                continue
        
        print(f"Done!")
        return river_name, masks, years, filenames
    
    def _calculate_grid_size(self, n_masks):
        """
        Calculate optimal grid layout.
        
        Parameters:
        -----------
        n_masks : int
            Number of masks to display
            
        Returns:
        --------
        tuple
            (n_rows, n_cols)
        """
        # Aim for roughly square grid, slightly wider
        n_cols = int(np.ceil(np.sqrt(n_masks * 1.3)))
        n_rows = int(np.ceil(n_masks / n_cols))
        return n_rows, n_cols
    
    def _downsample_mask(self, mask, max_dim=300):
        """
        Downsample mask to thumbnail size for faster display.
        
        Parameters:
        -----------
        mask : numpy.ndarray
            Full resolution mask
        max_dim : int, optional
            Maximum dimension for thumbnail (default: 300)
            
        Returns:
        --------
        numpy.ndarray
            Downsampled mask
        """
        height, width = mask.shape
        
        # Calculate zoom factor to fit within max_dim
        scale = min(max_dim / height, max_dim / width)
        
        # If already small enough, return as-is
        if scale >= 1.0:
            return mask
        
        # Downsample using nearest neighbor to preserve binary values
        downsampled = zoom(mask, scale, order=0)
        
        return downsampled
    
    def _is_selected(self, river_name, year, filename):
        """
        Check if a mask is selected for deletion.
        
        Parameters:
        -----------
        river_name : str
            River name
        year : int
            Year
        filename : str
            Filename
            
        Returns:
        --------
        bool
            True if selected for deletion
        """
        key = (river_name, year, filename)
        return self.selections.get(key, False)
    
    def _toggle_selection(self, river_name, year, filename):
        """
        Toggle selection status for a mask.
        
        Parameters:
        -----------
        river_name : str
            River name
        year : int
            Year
        filename : str
            Filename
        """
        key = (river_name, year, filename)
        self.selections[key] = not self.selections.get(key, False)
    
    def _on_click(self, event):
        """
        Handle click events on mask images.
        
        Parameters:
        -----------
        event : matplotlib.backend_bases.MouseEvent
            Click event
        """
        if event.inaxes is None:
            return
        
        # Find which axis was clicked
        for i, ax in enumerate(self.axes):
            if ax == event.inaxes and i < len(self.current_masks):
                river_name = self.current_river_name
                year = self.current_years[i]
                filename = self.current_filenames[i]
                
                # Toggle selection
                self._toggle_selection(river_name, year, filename)
                
                # Update border
                self._update_border(i)
                
                # Redraw
                self.fig.canvas.draw_idle()
                break
    
    def _update_border(self, mask_idx):
        """
        Update the border around a mask based on selection status.
        
        Parameters:
        -----------
        mask_idx : int
            Index of the mask in current display
        """
        river_name = self.current_river_name
        year = self.current_years[mask_idx]
        filename = self.current_filenames[mask_idx]
        
        selected = self._is_selected(river_name, year, filename)
        
        # Remove old border
        if self.borders[mask_idx] is not None:
            self.borders[mask_idx].remove()
        
        # Add new border if selected
        if selected:
            ax = self.axes[mask_idx]
            border = Rectangle((0, 0), 1, 1, transform=ax.transAxes,
                             fill=False, edgecolor='red', linewidth=4)
            ax.add_patch(border)
            self.borders[mask_idx] = border
        else:
            self.borders[mask_idx] = None
    
    def _display_river(self):
        """
        Display all masks for the current river in a grid.
        """
        # Clear previous figure and clean up memory
        if self.fig is not None:
            plt.close(self.fig)
            self.fig = None
            self.axes = []
            self.borders = []
        
        # Load masks for current river
        self.current_river_name, self.current_masks, self.current_years, self.current_filenames = \
            self._load_masks_for_river(self.current_river_idx)
        
        if len(self.current_masks) == 0:
            print(f"No masks found for {self.rivers[self.current_river_idx]}")
            return
        
        # Calculate grid size
        n_masks = len(self.current_masks)
        n_rows, n_cols = self._calculate_grid_size(n_masks)
        
        # Create figure
        fig_width = min(20, n_cols * 3)
        fig_height = min(16, n_rows * 3 + 2)  # +2 for buttons
        self.fig = plt.figure(figsize=(fig_width, fig_height))
        
        # Add title
        river_name = self.current_river_name
        title = f"{river_name} ({self.current_river_idx + 1}/{len(self.rivers)})"
        title += f"\nMasks: {n_masks} | Selected for deletion: {sum(1 for k, v in self.selections.items() if v and k[0] == river_name)}"
        self.fig.suptitle(title, fontsize=14, fontweight='bold')
        
        # Create grid of axes
        self.axes = []
        self.borders = []
        
        # Create custom colormap once (white for 0, blue for 1)
        from matplotlib.colors import ListedColormap
        colors = ['white', '#3366CC']  # white, blue
        cmap = ListedColormap(colors)
        
        for i in range(n_masks):
            row = i // n_cols
            col = i % n_cols
            
            # Create axis (leave room at bottom for buttons)
            ax = self.fig.add_subplot(n_rows + 1, n_cols, i + 1)
            
            # Downsample mask to thumbnail
            mask_full = self.current_masks[i]
            mask_thumb = self._downsample_mask(mask_full)
            
            # Display mask with custom colormap
            ax.imshow(mask_thumb, cmap=cmap, vmin=0, vmax=1, interpolation='nearest')
            ax.set_title(f"{self.current_years[i]}", fontsize=10)
            ax.axis('off')
            
            self.axes.append(ax)
            self.borders.append(None)
            
            # Update border if already selected
            self._update_border(i)
        
        # Hide extra subplots
        for i in range(n_masks, n_rows * n_cols):
            ax = self.fig.add_subplot(n_rows + 1, n_cols, i + 1)
            ax.axis('off')
        
        # Add buttons at the bottom
        button_height = 0.04
        button_width = 0.12
        button_y = 0.02
        spacing = 0.02
        
        # Calculate starting x position to center buttons
        total_width = 6 * button_width + 5 * spacing
        start_x = (1 - total_width) / 2
        
        # Previous River button
        ax_prev = self.fig.add_axes([start_x, button_y, button_width, button_height])
        self.btn_prev = Button(ax_prev, 'Previous River')
        self.btn_prev.on_clicked(lambda x: self._on_previous())
        
        # Skip River button
        ax_skip = self.fig.add_axes([start_x + button_width + spacing, button_y, button_width, button_height])
        self.btn_skip = Button(ax_skip, 'Skip River')
        self.btn_skip.on_clicked(lambda x: self._on_skip())
        
        # Next River button
        ax_next = self.fig.add_axes([start_x + 2 * (button_width + spacing), button_y, button_width, button_height])
        self.btn_next = Button(ax_next, 'Next River')
        self.btn_next.on_clicked(lambda x: self._on_next())
        
        # Select All button
        ax_select_all = self.fig.add_axes([start_x + 3 * (button_width + spacing), button_y, button_width, button_height])
        self.btn_select_all = Button(ax_select_all, 'Select All')
        self.btn_select_all.on_clicked(lambda x: self._on_select_all())
        
        # Deselect All button
        ax_deselect_all = self.fig.add_axes([start_x + 4 * (button_width + spacing), button_y, button_width, button_height])
        self.btn_deselect_all = Button(ax_deselect_all, 'Deselect All')
        self.btn_deselect_all.on_clicked(lambda x: self._on_deselect_all())
        
        # Finish button
        ax_finish = self.fig.add_axes([start_x + 5 * (button_width + spacing), button_y, button_width, button_height])
        self.btn_finish = Button(ax_finish, 'Finish')
        self.btn_finish.on_clicked(lambda x: self._on_finish())
        
        # Connect click event
        self.fig.canvas.mpl_connect('button_press_event', self._on_click)
        
        plt.tight_layout(rect=[0, 0.07, 1, 0.96])
        plt.show()
    
    def _on_previous(self):
        """Handle Previous River button click."""
        if self.current_river_idx > 0:
            self.current_river_idx -= 1
            self._display_river()
        else:
            print("Already at first river")
    
    def _on_skip(self):
        """Handle Skip River button click."""
        self._on_next()
    
    def _on_next(self):
        """Handle Next River button click."""
        if self.current_river_idx < len(self.rivers) - 1:
            self.current_river_idx += 1
            self._display_river()
        else:
            print("Already at last river - click 'Finish' to export results")
    
    def _on_select_all(self):
        """Handle Select All button click."""
        river_name = self.current_river_name
        
        for i in range(len(self.current_masks)):
            year = self.current_years[i]
            filename = self.current_filenames[i]
            key = (river_name, year, filename)
            self.selections[key] = True
            self._update_border(i)
        
        # Update title
        self._update_title()
        self.fig.canvas.draw_idle()
    
    def _on_deselect_all(self):
        """Handle Deselect All button click."""
        river_name = self.current_river_name
        
        for i in range(len(self.current_masks)):
            year = self.current_years[i]
            filename = self.current_filenames[i]
            key = (river_name, year, filename)
            self.selections[key] = False
            self._update_border(i)
        
        # Update title
        self._update_title()
        self.fig.canvas.draw_idle()
    
    def _update_title(self):
        """Update the title with current selection count."""
        river_name = self.current_river_name
        n_masks = len(self.current_masks)
        n_selected = sum(1 for k, v in self.selections.items() if v and k[0] == river_name)
        
        title = f"{river_name} ({self.current_river_idx + 1}/{len(self.rivers)})"
        title += f"\nMasks: {n_masks} | Selected for deletion: {n_selected}"
        self.fig.suptitle(title, fontsize=14, fontweight='bold')
    
    def _on_finish(self):
        """Handle Finish button click - export results and close."""
        plt.close(self.fig)
        self.export_results()
        print("\nQA/QC session complete!")
    
    def export_results(self):
        """
        Export selected masks to CSV.
        """
        output_path = os.path.join(self.working_directory, 'RiverMapping', 'MaskQC', 
                                   'mask_grid_QC_summary.csv')
        
        # Create output directory if needed
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # Collect all selected masks
        selected_masks = []
        for (river_name, year, filename), selected in self.selections.items():
            if selected:
                selected_masks.append({
                    'river_name': river_name,
                    'year': year,
                    'filename': filename
                })
        
        # Create DataFrame and save
        if len(selected_masks) > 0:
            df = pd.DataFrame(selected_masks)
            df = df.sort_values(['river_name', 'year'])
            df.to_csv(output_path, index=False)
            print(f"\nExported {len(selected_masks)} flagged masks to:")
            print(f"  {output_path}")
        else:
            print("\nNo masks were flagged for deletion")
            # Still create empty CSV with headers
            df = pd.DataFrame(columns=['river_name', 'year', 'filename'])
            df.to_csv(output_path, index=False)
            print(f"  Empty CSV created at: {output_path}")
        
        # Print summary
        print(f"\nSummary:")
        print(f"  Rivers reviewed: {len(self.rivers)}")
        print(f"  Total masks flagged: {len(selected_masks)}")
        
        if len(selected_masks) > 0:
            by_river = df.groupby('river_name').size()
            print(f"  Flagged by river:")
            for river, count in by_river.items():
                print(f"    {river}: {count} masks")
    
    def run(self):
        """
        Start the interactive QA/QC session.
        """
        if len(self.rivers) == 0:
            print(f"ERROR: No river directories found with reach_1/Cleaned structure")
            return
        
        print(f"Starting QA/QC for all rivers")
        print(f"Found {len(self.rivers)} rivers to review")
        print("\nInstructions:")
        print("  - Click on a mask to toggle deletion flag (red border)")
        print("  - Use 'Select All' / 'Deselect All' for batch operations")
        print("  - Navigate: 'Previous River' / 'Skip River' / 'Next River'")
        print("  - Click 'Finish' when done to export results\n")
        
        self._display_river()


# Example usage
if __name__ == "__main__":
    
    # Configuration
    working_directory = r"E:\Dissertation\Data"  # Update to your working directory
    
    # Create and run QA/QC tool (will review all rivers in RiverMasks directory)
    qc_tool = MaskGridQC(working_directory)
    qc_tool.run()
# Out:
# Starting QA/QC for all rivers
# Found 131 rivers to review
#
# Instructions:
#   - Click on a mask to toggle deletion flag (red border)
#   - Use 'Select All' / 'Deselect All' for batch operations
#   - Navigate: 'Previous River' / 'Skip River' / 'Next River'
#   - Click 'Finish' when done to export results
#
# Loading 18 masks for Aladan_VerkhoyanskiyPerevoz... Done!
# C:\Users\huckr\AppData\Local\Temp\ipykernel_41360\3212014501.py:443: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.07, 1, 0.96])
# Loading 36 masks for Amazonas_Jatuarana... Done!
# Loading 30 masks for Amazonas_Tamshiyacu... Done!
# Loading 28 masks for AmuDarya_Kerki... Done!
# Loading 26 masks for Amur_Khabarovsk... Done!
# Loading 37 masks for Amur_Komsomolsk... Done!
# Loading 23 masks for Amyl_Kachulka... Done!
# Loading 36 masks for Apalachicola_NearBlountstown... Done!
# Loading 34 masks for Araguaia_Aruana... Done!
# Loading 35 masks for Araguaia_LuizAlves... Done!
# Loading 36 masks for Araguaia_SaoFelixDoAraguaia... Done!
# Loading 28 masks for Beas_MandiPlain... Done!
# Loading 35 masks for Beni_Rurrenabaque... Done!
# Loading 12 masks for Benue_Ibi... Done!
# Loading 19 masks for Benue_Umaisha... Done!
# Loading 28 masks for Bhareli_NTRoadCrossing... Done!
# Loading 22 masks for BolshayaKet_Rodyonovka... Done!
# Loading 33 masks for Brahmaputra_Bahadurabad... Done!
# Loading 31 masks for Brahmaputra_Pandu... Done!
# Loading 37 masks for Brahmaputra_Pasighat... Done!
# Loading 32 masks for Brahmaputra_Yangcun... Done!
# Loading 20 masks for Chari_Bousso... Done!
# Loading 18 masks for Chari_Guelengdeng... Done!
# Loading 18 masks for Chari_Ndjamena... Done!
# Loading 20 masks for Chari_Sahr... Done!
# Loading 19 masks for Chenab_Akhnoor... Done!
# Loading 34 masks for Cuiaba_PortoDoAlegre... Done!
# Loading 34 masks for Demini_PostoAjuricaba... Done!
# Loading 38 masks for Fraser_Hope... Done!
# Loading 33 masks for Gandak_Devghat... Done!
# Loading 31 masks for Gandak_Dumariaghat... Done!
# Loading 24 masks for Gandak_Triveni... Done!
# Loading 34 masks for Ganges_Paksey... Done!
# Loading 36 masks for Guapore_Pimenteiras... Done!
# Loading 34 masks for Helmand_Kajaki... Done!
# Loading 30 masks for Helmand_Malakhan... Done!
# Loading 24 masks for HuangHe_Huayuankou... Done!
# Loading 35 masks for HuangHe_TanglaiQu... Done!
# Loading 25 masks for Ica_IpirangaVelho... Done!
# Loading 33 masks for Indus_Attock... Done!
# Loading 19 masks for Indus_Kotri... Done!
# Loading 35 masks for Irrawaddy_Katha... Done!
# Loading 32 masks for Irrawaddy_Sagaing... Done!
# Loading 32 masks for Irtysh_Bobrovsky... Done!
# Loading 34 masks for Irtysh_Hanti-Mansisk... Done!
# Loading 31 masks for Irtysh_Pavlodar... Done!
# Loading 31 masks for Irtysh_Semiyarskoje... Done!
# Loading 31 masks for Irtysh_Pavlodar... Done!
# Loading 31 masks for Irtysh_Semiyarskoje... Done!
# Loading 29 masks for Itacuai_LadarioJusante... Done!
# Loading 35 masks for Jurua_EirunepeMontante... Done!
# Loading 35 masks for Jurua_SantosDumont... Done!
# Loading 38 masks for Jutai_PortoSeguro... Done!
# Loading 20 masks for Kamchatka_Kozyrevsk... Done!
# Loading 31 masks for Kan_Kansk... Done!
# Loading 14 masks for Katun_Srostki... Done!
# Loading 21 masks for Kokcha_Khojaghar... Done!
# Loading 15 masks for Krishna_Vijayawada... Done!
# Loading 18 masks for Lena_Tabaga... Done!
# Loading 26 masks for Liard_UpperCrossing... Done!
# Loading 16 masks for Logone_Bongor... Done!
# Loading 16 masks for Logone_Lai... Done!
# Loading 36 masks for Madeira_Humaita... Done!
# Loading 38 masks for MadreDeDios_CachuelaEsperanza... Done!
# Loading 33 masks for Magdalena_Calamar... Done!
# Loading 31 masks for Magdalena_PuertoBerrio... Done!
# Loading 36 masks for Mamore_Guajara-Mirim... Done!
# Loading 36 masks for Mamore_PuertoSiles... Done!
# Loading 33 masks for Manas_Mathanguri... Done!
# Loading 28 masks for Maranon_Borja... Done!
# Loading 32 masks for Maranon_SanRegis... Done!
# Loading 19 masks for Mbam_Goura... Done!
# Loading 35 masks for Mekong_Kratie... Done!
# Loading 19 masks for Mbam_Goura... Done!
# Loading 35 masks for Mekong_Kratie... Done!
# Loading 36 masks for Mortes_SantoAntonioDoLeverger... Done!
# Loading 28 masks for Napo_Bellavista... Done!
# Loading 23 masks for Napo_NvoRocafuerte... Done!
# Loading 19 masks for Naryn_UstKekirim... Done!
# Loading 29 masks for Niger_Tossaye... Done!
# Loading 30 masks for Ob_Barnaul... Done!
# Loading 22 masks for Ob_Kolpashevo... Done!
# Loading 24 masks for Ob_Mogochin... Done!
# Loading 22 masks for Ob_Kolpashevo... Done!
# Loading 30 masks for Ob_Barnaul... Done!
# Loading 22 masks for Ob_Kolpashevo... Done!
# Loading 24 masks for Ob_Mogochin... Done!
# Loading 22 masks for Ob_Kolpashevo... Done!
# Loading 24 masks for Ob_Mogochin... Done!
# Loading 31 masks for Ob_Phominskoje... Done!
# Loading 17 masks for Ob_Prokhorkino... Done!
# Loading 27 masks for Orinoco_CiudadBolivar... Done!
# Loading 34 masks for Orinoco_Musinacio... Done!
# Loading 30 masks for Panj_NizPyandzh... Done!
# Loading 37 masks for Paraguay_Asuncion... Done!
# Loading 36 masks for Paraguay_PortoMurtinho... Done!
# Loading 36 masks for Parana_Chapeton... Done!
# Loading 36 masks for Paraguay_PortoMurtinho... Done!
# Loading 36 masks for Parana_Chapeton... Done!
# Loading 27 masks for Parana_Corrientes... Done!
# Loading 36 masks for Peace_FifthMeridian... Done!
# Loading 34 masks for Pilcomayo_VillaMontes... Done!
# Loading 34 masks for Porcupine_NearFortYukon... Done!
# Loading 36 masks for Purus_Canutama... Done!
# Loading 36 masks for Purus_Labrea... Done!
# Loading 36 masks for Purus_SeringalDaCaridade... Done!
# Loading 35 masks for Purus_ValparaisoMontante... Done!
# Loading 36 masks for Red_Index... Done!
# Loading 29 masks for Rufiji_Stigler... Done!
# Loading 22 masks for Salinas_SanAugustin... Done!
# Loading 21 masks for Sangha_Ouesso... Done!
# Loading 33 masks for SaoFrancisco_BomJesusDaLapa... Done!
# Loading 36 masks for SaoFrancisco_Morpara... Done!
# Loading 30 masks for SaptKosi_Baltara... Done!
# Loading 32 masks for SaptKosi_ChataraKothu... Done!
# Loading 29 masks for Selenga_Naushki... Done!
# Loading 38 masks for Solimoes_Itapeua... Done!
# Loading 38 masks for Solimoes_Manacapuru... Done!
# Loading 33 masks for Solimoes_SantoAntonioDoIca... Done!
# Loading 31 masks for Solimoes_SaoPauloDeOlivenca... Done!
# Loading 25 masks for Solimoes_Tabatinga... Done!
# Loading 37 masks for SonghuaJiang_Haerbin... Done!
# Loading 26 masks for Taku_NearTulsequa... Done!
# Loading 21 masks for Tanana_NearHardingLake... Done!
# Loading 32 masks for Tarauaca_Envira... Done!
# Loading 14 masks for Tista_AndersonBr... Done!
# Loading 18 masks for Tista_Kaunia... Done!
# Loading 34 masks for Tisza_Vylok... Done!
# Loading 35 masks for Trinity_Romayor... Done!
# Loading 35 masks for Ucayali_Atalaya... Done!
# Loading 35 masks for Ucayali_Pucallpa... Done!
# Loading 34 masks for Ucayali_Requena... Done!
# Loading 28 masks for Ural_Kushum... Done!
# Loading 21 masks for Vilyuy_KhatyrykKhoma... Done!
# Loading 36 masks for White_DevallsBluff... Done!
# Loading 36 masks for White_Petersburg... Done!
# Loading 38 masks for Yangtze_Datong... Done!
# Loading 37 masks for Yellowstone_NearSidney... Done!
# Loading 30 masks for Yukon_Eagle... Done!
# Loading 19 masks for Yukon_NearStevensVillage... Done!
# Loading 34 masks for Zambezi_LukuluMission... Done!
# Loading 37 masks for Zambezi_Matundo-Cais... Done!
# Loading 34 masks for Zambezi_Sesheke... Done!
#
# Exported 45 flagged masks to:
#   E:\Dissertation\Data\RiverMapping\MaskQC\mask_grid_QC_summary.csv
#
# Summary:
#   Rivers reviewed: 131
#   Total masks flagged: 45
#   Flagged by river:
#     Benue_Umaisha: 3 masks
#     BolshayaKet_Rodyonovka: 1 masks
#     Chari_Bousso: 2 masks
#     Chari_Guelengdeng: 1 masks
#     Chari_Sahr: 2 masks
#     Helmand_Kajaki: 3 masks
#     Helmand_Malakhan: 4 masks
#     Irtysh_Bobrovsky: 2 masks
#     Irtysh_Hanti-Mansisk: 3 masks
#     Irtysh_Semiyarskoje: 1 masks
#     Kan_Kansk: 1 masks
#     Magdalena_PuertoBerrio: 2 masks
#     Manas_Mathanguri: 2 masks
#     Mbam_Goura: 2 masks
#     Niger_Tossaye: 4 masks
#     Orinoco_CiudadBolivar: 2 masks
#     Orinoco_Musinacio: 3 masks
#     Parana_Chapeton: 2 masks
#     Pilcomayo_VillaMontes: 1 masks
#     Porcupine_NearFortYukon: 1 masks
#     Sangha_Ouesso: 1 masks
#     Vilyuy_KhatyrykKhoma: 1 masks
#     Zambezi_LukuluMission: 1 masks
#
# QA/QC session complete!

# %% [markdown]
# ## Delete files flagged during additional mask QC effort

# %%
"""
Quick script to delete specific flagged mask files

Author: James (Huck) Rees
Date: January 30, 2026
"""

import os

# Configuration
working_directory = r"E:\Dissertation\Data"

# List of files to delete
files_to_delete = [
    "Benue_Umaisha_reach_1_1987_DSWE_level_2_cleaned.tif",
    "Benue_Umaisha_reach_1_1991_DSWE_level_2_cleaned.tif",
    "Benue_Umaisha_reach_1_2003_DSWE_level_2_cleaned.tif",
    "BolshayaKet_Rodyonovka_reach_1_2022_DSWE_level_2_cleaned.tif",
    "Chari_Bousso_reach_1_2001_DSWE_level_2_cleaned.tif",
    "Chari_Bousso_reach_1_2003_DSWE_level_2_cleaned.tif",
    "Chari_Guelengdeng_reach_1_2003_DSWE_level_2_cleaned.tif",
    "Chari_Sahr_reach_1_1986_DSWE_level_2_cleaned.tif",
    "Chari_Sahr_reach_1_1987_DSWE_level_2_cleaned.tif",
    "Helmand_Kajaki_reach_1_2000_DSWE_level_2_cleaned.tif",
    "Helmand_Kajaki_reach_1_2001_DSWE_level_2_cleaned.tif",
    "Helmand_Kajaki_reach_1_2002_DSWE_level_2_cleaned.tif",
    "Helmand_Malakhan_reach_1_2008_DSWE_level_2_cleaned.tif",
    "Helmand_Malakhan_reach_1_2018_DSWE_level_2_cleaned.tif",
    "Helmand_Malakhan_reach_1_2021_DSWE_level_2_cleaned.tif",
    "Helmand_Malakhan_reach_1_2022_DSWE_level_2_cleaned.tif",
    "Irtysh_Bobrovsky_reach_1_1990_DSWE_level_2_cleaned.tif",
    "Irtysh_Bobrovsky_reach_1_1992_DSWE_level_2_cleaned.tif",
    "Irtysh_Hanti-Mansisk_reach_1_1985_DSWE_level_2_cleaned.tif",
    "Irtysh_Hanti-Mansisk_reach_1_1993_DSWE_level_2_cleaned.tif",
    "Irtysh_Hanti-Mansisk_reach_1_2007_DSWE_level_2_cleaned.tif",
    "Irtysh_Semiyarskoje_reach_1_1995_DSWE_level_2_cleaned.tif",
    "Kan_Kansk_reach_1_1997_DSWE_level_2_cleaned.tif",
    "Magdalena_PuertoBerrio_reach_1_1997_DSWE_level_2_cleaned.tif",
    "Magdalena_PuertoBerrio_reach_1_2010_DSWE_level_2_cleaned.tif",
    "Manas_Mathanguri_reach_1_1995_DSWE_level_2_cleaned.tif",
    "Manas_Mathanguri_reach_1_1997_DSWE_level_2_cleaned.tif",
    "Mbam_Goura_reach_1_1986_DSWE_level_2_cleaned.tif",
    "Mbam_Goura_reach_1_1987_DSWE_level_2_cleaned.tif",
    "Niger_Tossaye_reach_1_1988_DSWE_level_2_cleaned.tif",
    "Niger_Tossaye_reach_1_1994_DSWE_level_2_cleaned.tif",
    "Niger_Tossaye_reach_1_1995_DSWE_level_2_cleaned.tif",
    "Niger_Tossaye_reach_1_2013_DSWE_level_2_cleaned.tif",
    "Orinoco_CiudadBolivar_reach_1_1990_DSWE_level_2_cleaned.tif",
    "Orinoco_CiudadBolivar_reach_1_1994_DSWE_level_2_cleaned.tif",
    "Orinoco_Musinacio_reach_1_1986_DSWE_level_2_cleaned.tif",
    "Orinoco_Musinacio_reach_1_1987_DSWE_level_2_cleaned.tif",
    "Orinoco_Musinacio_reach_1_2011_DSWE_level_2_cleaned.tif",
    "Parana_Chapeton_reach_1_1990_DSWE_level_2_cleaned.tif",
    "Parana_Chapeton_reach_1_1994_DSWE_level_2_cleaned.tif",
    "Pilcomayo_VillaMontes_reach_1_1988_DSWE_level_2_cleaned.tif",
    "Porcupine_NearFortYukon_reach_1_1989_DSWE_level_2_cleaned.tif",
    "Sangha_Ouesso_reach_1_1994_DSWE_level_2_cleaned.tif",
    "Vilyuy_KhatyrykKhoma_reach_1_2003_DSWE_level_2_cleaned.tif",
    "Zambezi_LukuluMission_reach_1_2010_DSWE_level_2_cleaned.tif"
]

# Delete files
deleted_count = 0
not_found_count = 0

for filename in files_to_delete:
    # Extract river name (everything before _reach_1_)
    river_name = filename.split('_reach_1_')[0]
    
    # Construct full path
    filepath = os.path.join(working_directory, 'RiverMapping', 'RiverMasks', 
                           river_name, 'reach_1', 'Cleaned', filename)
    
    # Delete if exists
    if os.path.exists(filepath):
        os.remove(filepath)
        print(f"Deleted: {filename}")
        deleted_count += 1
    else:
        print(f"Not found: {filename}")
        not_found_count += 1

print(f"\nSummary:")
print(f"  Deleted: {deleted_count}")
print(f"  Not found: {not_found_count}")
print(f"  Total: {len(files_to_delete)}")
# Out:
# Deleted: Benue_Umaisha_reach_1_1987_DSWE_level_2_cleaned.tif
# Deleted: Benue_Umaisha_reach_1_1991_DSWE_level_2_cleaned.tif
# Deleted: Benue_Umaisha_reach_1_2003_DSWE_level_2_cleaned.tif
# Deleted: BolshayaKet_Rodyonovka_reach_1_2022_DSWE_level_2_cleaned.tif
# Deleted: Chari_Bousso_reach_1_2001_DSWE_level_2_cleaned.tif
# Deleted: Chari_Bousso_reach_1_2003_DSWE_level_2_cleaned.tif
# Deleted: Chari_Guelengdeng_reach_1_2003_DSWE_level_2_cleaned.tif
# Deleted: Chari_Sahr_reach_1_1986_DSWE_level_2_cleaned.tif
# Deleted: Chari_Sahr_reach_1_1987_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Kajaki_reach_1_2000_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Kajaki_reach_1_2001_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Kajaki_reach_1_2002_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Malakhan_reach_1_2008_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Malakhan_reach_1_2018_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Malakhan_reach_1_2021_DSWE_level_2_cleaned.tif
# Deleted: Helmand_Malakhan_reach_1_2022_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Bobrovsky_reach_1_1990_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Bobrovsky_reach_1_1992_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Hanti-Mansisk_reach_1_1985_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Hanti-Mansisk_reach_1_1993_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Hanti-Mansisk_reach_1_2007_DSWE_level_2_cleaned.tif
# Deleted: Irtysh_Semiyarskoje_reach_1_1995_DSWE_level_2_cleaned.tif
# Deleted: Kan_Kansk_reach_1_1997_DSWE_level_2_cleaned.tif
# Deleted: Magdalena_PuertoBerrio_reach_1_1997_DSWE_level_2_cleaned.tif
# Deleted: Magdalena_PuertoBerrio_reach_1_2010_DSWE_level_2_cleaned.tif
# Deleted: Manas_Mathanguri_reach_1_1995_DSWE_level_2_cleaned.tif
# Deleted: Manas_Mathanguri_reach_1_1997_DSWE_level_2_cleaned.tif
# Deleted: Mbam_Goura_reach_1_1986_DSWE_level_2_cleaned.tif
# Deleted: Mbam_Goura_reach_1_1987_DSWE_level_2_cleaned.tif
# Deleted: Niger_Tossaye_reach_1_1988_DSWE_level_2_cleaned.tif
# Deleted: Niger_Tossaye_reach_1_1994_DSWE_level_2_cleaned.tif
# Deleted: Niger_Tossaye_reach_1_1995_DSWE_level_2_cleaned.tif
# Deleted: Niger_Tossaye_reach_1_2013_DSWE_level_2_cleaned.tif
# Deleted: Orinoco_CiudadBolivar_reach_1_1990_DSWE_level_2_cleaned.tif
# Deleted: Orinoco_CiudadBolivar_reach_1_1994_DSWE_level_2_cleaned.tif
# Deleted: Orinoco_Musinacio_reach_1_1986_DSWE_level_2_cleaned.tif
# Deleted: Orinoco_Musinacio_reach_1_1987_DSWE_level_2_cleaned.tif
# Deleted: Orinoco_Musinacio_reach_1_2011_DSWE_level_2_cleaned.tif
# Deleted: Parana_Chapeton_reach_1_1990_DSWE_level_2_cleaned.tif
# Deleted: Parana_Chapeton_reach_1_1994_DSWE_level_2_cleaned.tif
# Deleted: Pilcomayo_VillaMontes_reach_1_1988_DSWE_level_2_cleaned.tif
# Deleted: Porcupine_NearFortYukon_reach_1_1989_DSWE_level_2_cleaned.tif
# Deleted: Sangha_Ouesso_reach_1_1994_DSWE_level_2_cleaned.tif
# Deleted: Vilyuy_KhatyrykKhoma_reach_1_2003_DSWE_level_2_cleaned.tif
# Deleted: Zambezi_LukuluMission_reach_1_2010_DSWE_level_2_cleaned.tif
#
# Summary:
#   Deleted: 45
#   Not found: 0
#   Total: 45

# %% [markdown]
# ## Export centroids for all chapter 2 river reaches

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import rasterio
import warnings
from pathlib import Path

def determine_study(river_name, mask_base_dir):
    """
    Determine which study a river belongs to based on mask encoding and river name.
    
    Parameters:
    -----------
    river_name : str
        Name of the river
    mask_base_dir : str
        Base directory containing river masks
        
    Returns:
    --------
    str
        Study name: 'Rees et al.', 'Greenberg et al.', or 'Zhao et al.'
    """
    # Hardcoded Rees study rivers
    rees_rivers = ['Beni', 'Bermejo', 'Koyukuk_Huslia', 'Yukon_Beaver']
    
    if river_name in rees_rivers:
        return 'Rees et al.'
    
    # Check mask encoding to differentiate Greenberg (0/1) vs Zhao (0/255)
    mask_dir = os.path.join(mask_base_dir, river_name, "Cleaned")
    
    if not os.path.exists(mask_dir):
        return 'Greenberg et al.'
    
    # Get first available mask
    tif_files = [f for f in os.listdir(mask_dir) if f.lower().endswith('.tif')]
    
    if len(tif_files) == 0:
        return 'Greenberg et al.'
    
    try:
        mask_path = os.path.join(mask_dir, tif_files[0])
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
            with rasterio.open(mask_path) as src:
                data = src.read(1)
        
        # Get unique values
        unique_vals = set(np.unique(data))
        
        # Check encoding
        if unique_vals <= {0, 1}:
            return 'Greenberg et al.'
        elif unique_vals <= {0, 255}:
            return 'Zhao et al.'
        else:
            return 'Greenberg et al.'
            
    except Exception as e:
        return 'Greenberg et al.'

def extract_reach_centroids(base_directory, output_gpkg, mask_base_dir=None):
    """
    Extract centroid coordinates from all reach polygon shapefiles and save as point geopackage.
    Handles multiple features per shapefile using ds_order field.
    Assigns study attribution based on mask encoding.
    
    Parameters:
    -----------
    base_directory : str
        Base directory containing river reach folders (e.g., ".../Reaches")
    output_gpkg : str
        Output path for the point geopackage file
    mask_base_dir : str, optional
        Base directory containing river masks (for study determination)
        If None, study attribution will be set to 'Unknown'
        
    Returns:
    --------
    geopandas.GeoDataFrame
        GeoDataFrame with point geometries and coordinates
    """
    
    print(f"Scanning reach directories in: {base_directory}\n")
    print(f"{'='*60}\n")
    
    # List to store reach data
    reach_data = []
    
    # Counters
    success_count = 0
    error_count = 0
    not_found_count = 0
    total_features = 0
    
    # Get all subdirectories (river folders)
    river_dirs = [d for d in os.listdir(base_directory) 
                  if os.path.isdir(os.path.join(base_directory, d))]
    river_dirs = sorted(river_dirs)
    
    print(f"Found {len(river_dirs)} river directories\n")
    
    for river_name in river_dirs:
        # Expected shapefile path
        shapefile_path = os.path.join(base_directory, river_name, f"{river_name}.shp")
        
        if not os.path.exists(shapefile_path):
            print(f"⚠ Not found: {river_name}")
            not_found_count += 1
            continue
        
        try:
            # Determine study attribution
            if mask_base_dir:
                study = determine_study(river_name, mask_base_dir)
            else:
                study = 'Unknown'
            
            # Read the shapefile
            gdf = gpd.read_file(shapefile_path)
            
            num_features = len(gdf)
            
            # Process each feature in the shapefile
            for idx, row in gdf.iterrows():
                # Get ds_order if it exists, otherwise use 1
                ds_order = row.get('ds_order', 1)
                
                # Get the polygon geometry
                polygon = row.geometry
                
                # Calculate centroid in the original projection (EPSG:3395)
                centroid_3395 = polygon.centroid
                
                # Convert centroid to lat/lon (EPSG:4326)
                centroid_gdf = gpd.GeoDataFrame(
                    geometry=[centroid_3395],
                    crs='EPSG:3395'
                )
                centroid_latlon = centroid_gdf.to_crs('EPSG:4326')
                
                # Extract coordinates
                lon = centroid_latlon.geometry.x.iloc[0]
                lat = centroid_latlon.geometry.y.iloc[0]
                
                # Get polygon bounds for reference
                bounds = polygon.bounds  # (minx, miny, maxx, maxy)
                
                # Store reach info
                reach_data.append({
                    'river_name': river_name,
                    'ds_order': int(ds_order),
                    'study': study,
                    'longitude': lon,
                    'latitude': lat,
                    'geometry': centroid_latlon.geometry.iloc[0],
                    'original_crs': 'EPSG:3395',
                    'bbox_minx': bounds[0],
                    'bbox_miny': bounds[1],
                    'bbox_maxx': bounds[2],
                    'bbox_maxy': bounds[3]
                })
                
                total_features += 1
            
            success_count += 1
            if num_features == 1:
                print(f"✓ Processed: {river_name} (1 feature) - {study}")
            else:
                print(f"✓ Processed: {river_name} ({num_features} features, ds_order 1-{num_features}) - {study}")
            
        except Exception as e:
            print(f"✗ Error processing {river_name}: {e}")
            error_count += 1
    
    # Create GeoDataFrame
    if len(reach_data) == 0:
        print("\n⚠ No reach data collected!")
        return None
    
    reaches_gdf = gpd.GeoDataFrame(
        reach_data,
        geometry='geometry',
        crs='EPSG:4326'
    )
    
    # Save to geopackage
    reaches_gdf.to_file(output_gpkg, driver='GPKG')
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"SUMMARY")
    print(f"{'='*60}")
    print(f"Total river directories: {len(river_dirs)}")
    print(f"✓ Successfully processed: {success_count} rivers")
    print(f"✓ Total features/points created: {total_features}")
    print(f"⚠ Shapefiles not found: {not_found_count}")
    print(f"✗ Errors encountered: {error_count}")
    
    # Show rivers with multiple features
    multi_feature_rivers = reaches_gdf.groupby('river_name').size()
    multi_feature_rivers = multi_feature_rivers[multi_feature_rivers > 1]
    
    if len(multi_feature_rivers) > 0:
        print(f"\n{'='*60}")
        print(f"RIVERS WITH MULTIPLE FEATURES")
        print(f"{'='*60}")
        for river, count in multi_feature_rivers.items():
            print(f"  {river}: {count} features")
    
    # Show breakdown by study
    study_counts = reaches_gdf['study'].value_counts()
    print(f"\n{'='*60}")
    print(f"BREAKDOWN BY STUDY")
    print(f"{'='*60}")
    for study, count in study_counts.items():
        print(f"  {study}: {count} reaches")
    
    print(f"\n{'='*60}")
    print(f"OUTPUT")
    print(f"{'='*60}")
    print(f"Point geopackage saved to: {output_gpkg}")
    print(f"Total points: {len(reaches_gdf)}")
    print(f"CRS: EPSG:4326 (WGS 84)")
    print(f"Attributes: river_name, ds_order, study, longitude, latitude, bbox info")
    
    # Print geographic extent
    print(f"\nGeographic extent:")
    print(f"  Latitude range: {reaches_gdf['latitude'].min():.2f}° to {reaches_gdf['latitude'].max():.2f}°")
    print(f"  Longitude range: {reaches_gdf['longitude'].min():.2f}° to {reaches_gdf['longitude'].max():.2f}°")
    
    return reaches_gdf

def create_summary_csv(reaches_gdf, output_csv):
    """
    Create a simple CSV summary of reach locations (optional).
    
    Parameters:
    -----------
    reaches_gdf : geopandas.GeoDataFrame
        GeoDataFrame with reach centroid data
    output_csv : str
        Output path for CSV file
    """
    # Create simple dataframe without geometry
    df = pd.DataFrame({
        'River_Name': reaches_gdf['river_name'],
        'DS_Order': reaches_gdf['ds_order'],
        'Study': reaches_gdf['study'],
        'Latitude': reaches_gdf['latitude'],
        'Longitude': reaches_gdf['longitude']
    })
    
    df.to_csv(output_csv, index=False)
    print(f"\nCSV summary saved to: {output_csv}")

if __name__ == "__main__":
    # Set your paths
    reaches_directory = r"E:\Dissertation\Data\RiverMapping\Reaches"
    masks_directory = r"E:\Dissertation\Data\RiverMapping\RiverMasks"
    output_geopackage = r"E:\Dissertation\Data\Overview\Reach_Centroids\reach_centroids.gpkg"
    output_csv = r"E:\Dissertation\Data\Overview\Reach_Centroids\reach_centroids.csv"
    
    # Extract centroids and create geopackage with study attribution
    reaches_gdf = extract_reach_centroids(reaches_directory, output_geopackage, mask_base_dir=masks_directory)
    
    # Optionally create CSV summary
    if reaches_gdf is not None:
        create_summary_csv(reaches_gdf, output_csv)
        
        print(f"\n{'='*60}")
        print("USAGE")
        print(f"{'='*60}")
        print("You can now open the .gpkg file in QGIS, ArcGIS, or other GIS software")
        print("to view all reach locations on a global map.")
        print("\nTo color-code by study, use the 'study' attribute:")
        print("  - Greenberg et al., 2024 (0/1 encoding)")
        print("  - Zhao et al., unpublished (0/255 encoding)")
        print("  - Rees et al., unpublished (Beni, Bermejo, Koyukuk_Huslia, Yukon_Beaver)")

# %% [markdown]
# ## World map showing Chapter 2 river reaches color coded by study

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.patches import Rectangle
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.ticker as mticker

# Set Arial font
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 8

def plot_global_reach_map(gpkg_path, output_path=None, dpi=300):
    """
    Create a minimalistic world map showing river reaches color-coded by study.
    
    Parameters:
    -----------
    gpkg_path : str
        Path to the reach centroids geopackage
    output_path : str, optional
        Path to save the figure. If None, displays interactively
    dpi : int
        Resolution for saved figure
    """
    
    # Load reach centroids
    reaches = gpd.read_file(gpkg_path)
    
    print(f"Loaded {len(reaches)} reach points")
    print(f"Studies: {reaches['study'].value_counts().to_dict()}")
    
    # Define colors for each study
    study_colors = {
        'Greenberg et al.': '#2E86AB',      # Blue
        'Zhao et al.': '#A23B72',     # Purple
        'Rees et al.': '#F18F01',     # Orange
        'Unknown': '#999999'                       # Gray
    }
    
    # Create figure with Robinson projection
    # Width = 6.5", height calculated to maintain aspect ratio
    fig = plt.figure(figsize=(6.5, 3.5))
    ax = plt.axes(projection=ccrs.Robinson())
    
    # Set global extent
    ax.set_global()
    
    # Add natural features with minimal styling
    ax.add_feature(cfeature.LAND, facecolor='#F5F5F5', edgecolor='none', zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor='#FFFFFF', edgecolor='none', zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.5, edgecolor='#CCCCCC', zorder=1)
    ax.add_feature(cfeature.BORDERS, linewidth=0.3, edgecolor='#DDDDDD', 
                   linestyle=':', zorder=1)
    
    # Plot reaches by study
    for study in study_colors.keys():
        study_reaches = reaches[reaches['study'] == study]
        
        if len(study_reaches) > 0:
            ax.scatter(
                study_reaches.geometry.x,
                study_reaches.geometry.y,
                c=study_colors[study],
                s=40,  # Increased marker size
                alpha=0.8,
                edgecolors='white',
                linewidths=0.5,
                transform=ccrs.PlateCarree(),
                label=f"{study} (n={len(study_reaches)})",
                zorder=3
            )
    
    # Add gridlines with coordinate labels
    gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='#DDDDDD', 
                      alpha=0.5, linestyle='--', zorder=2)
    gl.top_labels = False
    gl.bottom_labels = False
    gl.left_labels = True
    gl.right_labels = True
    gl.xlabel_style = {'size': 8, 'color': '#666666'}
    gl.ylabel_style = {'size': 8, 'color': '#666666'}
    gl.xlocator = mticker.FixedLocator([-180, -120, -60, 0, 60, 120, 180])
    gl.ylocator = mticker.FixedLocator([-60, -30, 0, 30, 60])
    
    # Add legend
    legend = ax.legend(
        loc='lower left',
        frameon=True,
        fancybox=False,
        shadow=False,
        fontsize=8,
        markerscale=1.2,
        framealpha=0.95,
        edgecolor='#CCCCCC'
    )
    legend.get_frame().set_linewidth(0.5)
    
    # Add title
    plt.title(
        '',
        fontsize=8,
        fontweight='normal',
        pad=10,
        loc='left'
    )
    
    # Clean layout
    plt.tight_layout()
    
    # Save or display
    if output_path:
        plt.savefig(output_path, dpi=dpi, bbox_inches='tight', facecolor='white')
        print(f"\nMap saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

def plot_global_reach_map_simple(gpkg_path, output_path=None, dpi=300):
    """
    Alternative version with even more minimal styling.
    
    Parameters:
    -----------
    gpkg_path : str
        Path to the reach centroids geopackage
    output_path : str, optional
        Path to save the figure. If None, displays interactively
    dpi : int
        Resolution for saved figure
    """
    
    # Load reach centroids
    reaches = gpd.read_file(gpkg_path)
    
    print(f"Loaded {len(reaches)} reach points")
    
    # Define colors for each study (darker, more saturated)
    study_colors = {
        'Greenberg et al.': '#0077B6',      # Deep Blue
        'Zhao et al.': '#9B2C2C',     # Deep Red
        'Rees et al.': '#D97706',     # Deep Orange
        'Unknown': '#6B7280'                       # Gray
    }
    
    # Create figure with Robinson projection
    fig = plt.figure(figsize=(6.5, 3.5), facecolor='white')
    ax = plt.axes(projection=ccrs.Robinson())
    
    # Set global extent
    ax.set_global()
    
    # Extremely minimal base map
    ax.add_feature(cfeature.LAND, facecolor='white', edgecolor='none', zorder=0)
    ax.add_feature(cfeature.OCEAN, facecolor='#F8FAFC', edgecolor='none', zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.3, edgecolor='#CBD5E1', zorder=1)
    
    # Plot reaches by study
    for study in study_colors.keys():
        study_reaches = reaches[reaches['study'] == study]
        
        if len(study_reaches) > 0:
            ax.scatter(
                study_reaches.geometry.x,
                study_reaches.geometry.y,
                c=study_colors[study],
                s=45,  # Increased marker size
                alpha=0.9,
                edgecolors='none',
                transform=ccrs.PlateCarree(),
                label=f"{study} (n={len(study_reaches)})",
                zorder=3
            )
    
    # Add gridlines with coordinate labels
    gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='#E5E7EB', 
                      alpha=0.7, linestyle='--', zorder=2)
    gl.top_labels = False
    gl.bottom_labels = False
    gl.left_labels = True
    gl.right_labels = True
    gl.xlabel_style = {'size': 8, 'color': '#6B7280'}
    gl.ylabel_style = {'size': 8, 'color': '#6B7280'}
    gl.xlocator = mticker.FixedLocator([-180, -120, -60, 0, 60, 120, 180])
    gl.ylocator = mticker.FixedLocator([-60, -30, 0, 30, 60])
    
    # Minimal legend
    legend = ax.legend(
        loc='lower left',
        frameon=False,
        fontsize=8,
        markerscale=1.0
    )
    
    # Simple title
    ax.text(
        0.01, 0.98,
        '',
        transform=ax.transAxes,
        fontsize=8,
        fontweight='600',
        verticalalignment='top',
        color='#1E293B'
    )
    
    # Remove axes outline
    ax.outline_patch.set_visible(False)
    
    plt.tight_layout()
    
    # Save or display
    if output_path:
        plt.savefig(output_path, dpi=dpi, bbox_inches='tight', facecolor='white')
        print(f"\nMap saved to: {output_path}")
    else:
        plt.show()
    
    return fig, ax

if __name__ == "__main__":
    # Set your paths
    gpkg_file = r"E:\Dissertation\Data\Overview\Reach_Centroids\reach_centroids.gpkg"
    output_file = r"E:\Dissertation\Manuscript\Figures\Figure1\global_reach_map.png"
    
    # Create the standard version
    print("Creating map...")
    fig, ax = plot_global_reach_map(gpkg_file, output_path=output_file, dpi=1000)
    
    # Or use the minimal version:
    # output_file_simple = r"C:\Users\huckr\Desktop\UCSB\Dissertation\Data\RiverMapping\global_reach_map_simple.png"
    # fig, ax = plot_global_reach_map_simple(gpkg_file, output_path=output_file_simple, dpi=300)
    
    print("\nDone!")
